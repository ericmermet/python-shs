# %% [markdown]
# # Analyse de données historiques avec Python
#
# Ce notebook propose des exercices pratiques pour analyser des données historiques avec Python. Vous apprendrez à :
# - Charger et nettoyer des données historiques (CSV, JSON)
# - Analyser des chronologies et des événements
# - Manipuler des dates historiques
# - Utiliser des APIs fournissant des données historiques
# - Créer des statistiques et des visualisations simples

# %% [markdown]
# ---
# # Partie 1 : Manipulation de données historiques locales
#
# ## 1.1 Chargement des données

# %%
import csv
import json
from collections import Counter, defaultdict

# Charger le fichier des rois de France
def charger_rois_france():
    """Charge les données des rois de France depuis un fichier CSV."""
    rois = []
    with open('data/rois_france.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        for row in reader:
            rois.append(row)
    return rois

rois = charger_rois_france()
print(f"Nombre de rois chargés : {len(rois)}")
print(f"\nPremier roi : {rois[0]}")
# Out:
# Nombre de rois chargés : 67
#
# Premier roi : {'nom': 'Clovis Ier', 'debut_regne': '481', 'fin_regne': '511', 'dynastie': 'Mérovingiens'}

# %%
# Afficher les 5 premiers rois
print("Les 5 premiers rois de France :")
print("-" * 60)
for roi in rois[:5]:
    print(f"{roi['nom']} ({roi['debut_regne']} - {roi['fin_regne']})")
    print(f"  Dynastie : {roi['dynastie']}")
# Out:
# Les 5 premiers rois de France :
# ------------------------------------------------------------
# Clovis Ier (481 - 511)
#   Dynastie : Mérovingiens
# Clotaire Ier (511 - 561)
#   Dynastie : Mérovingiens
# Chilpéric Ier (561 - 584)
#   Dynastie : Mérovingiens
# Clotaire II (584 - 629)
#   Dynastie : Mérovingiens
# Dagobert Ier (629 - 639)
#   Dynastie : Mérovingiens

# %% [markdown]
# ## 1.2 Exercice : Analyse des dynasties
#
# **Objectif** : Compter le nombre de rois par dynastie et identifier la dynastie la plus longue.

# %%
# Exercice 1 : Compter les rois par dynastie

def compter_par_dynastie(rois):
    """Compte le nombre de rois par dynastie."""
    # À compléter : utiliser Counter ou un dictionnaire
    compteur = Counter(roi['dynastie'] for roi in rois)
    return compteur

dynasties = compter_par_dynastie(rois)
print("Nombre de rois par dynastie :")
for dynastie, nombre in dynasties.most_common():
    print(f"  {dynastie} : {nombre} rois")
# Out:
# Nombre de rois par dynastie :
#   Capétiens : 15 rois
#   Mérovingiens : 14 rois
#   Carolingiens : 12 rois
#   Valois : 7 rois
#   Bourbons : 7 rois
#   Valois-Angoulême : 5 rois
#   Robertiens : 2 rois
#   Bonaparte : 2 rois
#   Bosonides : 1 rois
#   Valois-Orléans : 1 rois
#   Orléans : 1 rois

# %%
# Exercice 2 : Calculer la durée de règne de chaque roi

def calculer_duree_regne(roi):
    """Calcule la durée de règne d'un roi en années."""
    try:
        debut = int(roi['debut_regne'])
        fin = int(roi['fin_regne'])
        return fin - debut
    except ValueError:
        return 0

# Trouver le roi avec le plus long règne
roi_plus_long = max(rois, key=calculer_duree_regne)
duree = calculer_duree_regne(roi_plus_long)
print(f"Roi avec le plus long règne : {roi_plus_long['nom']}")
print(f"Durée : {duree} ans ({roi_plus_long['debut_regne']} - {roi_plus_long['fin_regne']})")
# Out:
# Roi avec le plus long règne : Louis XIV
# Durée : 72 ans (1643 - 1715)

# %%
# Exercice 3 : Top 5 des règnes les plus longs

# À compléter : trier les rois par durée de règne et afficher le top 5
rois_tries = sorted(rois, key=calculer_duree_regne, reverse=True)

print("Top 5 des règnes les plus longs :")
print("-" * 50)
for i, roi in enumerate(rois_tries[:5], 1):
    duree = calculer_duree_regne(roi)
    print(f"{i}. {roi['nom']} : {duree} ans")
# Out:
# Top 5 des règnes les plus longs :
# --------------------------------------------------
# 1. Louis XIV : 72 ans
# 2. Louis XV : 59 ans
# 3. Clotaire Ier : 50 ans
# 4. Philippe Ier : 48 ans
# 5. Charlemagne : 46 ans

# %% [markdown]
# ## 1.3 Exercice : Analyse des événements historiques

# %%
# Charger les événements historiques
def charger_evenements():
    """Charge les événements historiques depuis un fichier JSON."""
    with open('data/evenements_france.json', 'r', encoding='utf-8') as f:
        return json.load(f)

evenements = charger_evenements()
print(f"Nombre d'événements chargés : {len(evenements)}")
print(f"\nExemple : {evenements[0]}")
# Out:
# Nombre d'événements chargés : 77
#
# Exemple : {'annee': 496, 'titre': 'Baptême de Clovis', 'description': "Clovis Ier, roi des Francs, est baptisé à Reims par l'évêque Remi, marquant la conversion du royaume franc au christianisme.", 'categorie': 'Religion'}

# %%
# Exercice 4 : Filtrer les événements par siècle

def obtenir_siecle(annee):
    """Retourne le siècle d'une année."""
    if annee <= 0:
        return f"{abs(annee) // 100 + 1}e siècle av. J.-C."
    return f"{(annee - 1) // 100 + 1}e siècle"

def filtrer_par_siecle(evenements, siecle):
    """Filtre les événements d'un siècle donné."""
    return [e for e in evenements if obtenir_siecle(e['annee']) == siecle]

# Événements du 18e siècle
evenements_18e = filtrer_par_siecle(evenements, "18e siècle")
print(f"Événements du 18e siècle ({len(evenements_18e)}) :")
for e in evenements_18e:
    print(f"  {e['annee']} : {e['titre']}")
# Out:
# Événements du 18e siècle (13) :
#   1715 : Mort de Louis XIV
#   1751 : Publication de l'Encyclopédie
#   1756 : Début de la Guerre de Sept Ans
#   1763 : Traité de Paris
#   1778 : Alliance franco-américaine
#   1789 : Prise de la Bastille
#   1789 : Déclaration des droits de l'homme
#   1791 : Fuite à Varennes
#   1792 : Proclamation de la République
#   1793 : Exécution de Louis XVI
#   1793 : Début de la Terreur
#   1794 : Chute de Robespierre
#   1799 : Coup d'État du 18 Brumaire

# %%
# Exercice 5 : Compter les événements par catégorie

def analyser_categories(evenements):
    """Analyse la répartition des événements par catégorie."""
    # À compléter
    categories = Counter(e['categorie'] for e in evenements)
    return categories

categories = analyser_categories(evenements)
print("Répartition par catégorie :")
for cat, nb in categories.most_common():
    print(f"  {cat} : {nb} événements")
# Out:
# Répartition par catégorie :
#   Politique : 35 événements
#   Militaire : 21 événements
#   Religion : 8 événements
#   Société : 7 événements
#   Culture : 5 événements
#   Économie : 1 événements

# %%
# Exercice 6 : Créer une frise chronologique textuelle

def creer_frise(evenements, debut, fin):
    """Crée une frise chronologique entre deux dates."""
    # Filtrer et trier
    selection = [e for e in evenements if debut <= e['annee'] <= fin]
    selection = sorted(selection, key=lambda e: e['annee'])
    
    print(f"\n Frise chronologique ({debut} - {fin})")
    print("=" * 60)
    
    for e in selection:
        print(f"\n{e['annee']} | {e['titre']}")
        print(f"         {e['description'][:80]}..." if len(e['description']) > 80 else f"         {e['description']}")

# Frise de la Révolution française
creer_frise(evenements, 1789, 1815)
# Out:
#  Frise chronologique (1789 - 1815)
# ============================================================
#
# 1789 | Prise de la Bastille
#          Le 14 juillet, le peuple de Paris prend d'assaut la forteresse de la Bastille, s...
#
# 1789 | Déclaration des droits de l'homme
#          L'Assemblée nationale adopte la Déclaration des droits de l'homme et du citoyen ...
#
# 1791 | Fuite à Varennes
#          Louis XVI et sa famille sont arrêtés à Varennes alors qu'ils tentent de fuir la ...
#
# 1792 | Proclamation de la République
#          La Convention nationale proclame la République française le 21 septembre, abolis...
#
# 1793 | Exécution de Louis XVI
#          Louis XVI est guillotiné place de la Révolution (actuelle place de la Concorde) ...
#
# 1793 | Début de la Terreur
#          Le Comité de salut public instaure la Terreur : des milliers de personnes seront...
#
# 1794 | Chute de Robespierre
#          Le 9 Thermidor (27 juillet), Robespierre est arrêté et exécuté, mettant fin à la...
#
# 1799 | Coup d'État du 18 Brumaire
#          Napoléon Bonaparte prend le pouvoir par un coup d'État et instaure le Consulat.
#
# 1804 | Sacre de Napoléon
#          Napoléon Bonaparte se fait couronner empereur des Français à Notre-Dame de Paris...
#
# 1804 | Code civil
#          Promulgation du Code civil, encore largement en vigueur aujourd'hui, unificateur...
#
# 1805 | Bataille d'Austerlitz
#          Napoléon remporte sa plus grande victoire contre les armées austro-russes, le 's...
#
# 1812 | Campagne de Russie
#          La Grande Armée envahit la Russie mais doit battre en retraite désastreuse face ...
#
# 1815 | Bataille de Waterloo
#          Napoléon est définitivement vaincu par les armées britanniques et prussiennes à ...

# %% [markdown]
# ---
# # Partie 2 : Données démographiques historiques

# %%
# Charger les données démographiques
def charger_demographie():
    """Charge les données démographiques historiques."""
    with open('data/demographie_france.csv', 'r', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        return list(reader)

demographie = charger_demographie()
print(f"Périodes chargées : {len(demographie)}")
print(f"\nColonnes : {list(demographie[0].keys())}")
# Out:
# Périodes chargées : 48
#
# Colonnes : ['annee', 'population']

# %%
# Exercice 7 : Analyser l'évolution de la population

def analyser_evolution_population(demographie):
    """Analyse l'évolution de la population française."""
    print("Évolution de la population française :")
    print("-" * 50)
    
    population_precedente = None
    
    for periode in demographie:
        annee = int(periode['annee'])
        population = int(periode['population'])
        
        # Calculer la variation
        if population_precedente:
            variation = ((population - population_precedente) / population_precedente) * 100
            symbole = "📈" if variation > 0 else "📉"
            print(f"{annee} : {population:,} habitants ({symbole} {variation:+.1f}%)")
        else:
            print(f"{annee} : {population:,} habitants")
        
        population_precedente = population

analyser_evolution_population(demographie)
# Out:
# Évolution de la population française :
# --------------------------------------------------
# 500 : 5,000,000 habitants
# 600 : 5,000,000 habitants (📉 +0.0%)
# 700 : 6,000,000 habitants (📈 +20.0%)
# 800 : 8,000,000 habitants (📈 +33.3%)
# 900 : 6,000,000 habitants (📉 -25.0%)
# 1000 : 6,500,000 habitants (📈 +8.3%)
# 1100 : 10,000,000 habitants (📈 +53.8%)
# 1200 : 12,000,000 habitants (📈 +20.0%)
# 1226 : 16,000,000 habitants (📈 +33.3%)
# 1300 : 17,000,000 habitants (📈 +6.2%)
# 1340 : 20,000,000 habitants (📈 +17.6%)
# 1350 : 12,000,000 habitants (📉 -40.0%)
# 1400 : 10,000,000 habitants (📉 -16.7%)
# 1450 : 12,000,000 habitants (📈 +20.0%)
# 1500 : 15,000,000 habitants (📈 +25.0%)
# 1550 : 18,000,000 habitants (📈 +20.0%)
# 1600 : 18,500,000 habitants (📈 +2.8%)
# 1650 : 18,000,000 habitants (📉 -2.7%)
# 1700 : 21,500,000 habitants (📈 +19.4%)
# 1750 : 24,500,000 habitants (📈 +14.0%)
# 1760 : 25,000,000 habitants (📈 +2.0%)
# 1770 : 26,000,000 habitants (📈 +4.0%)
# 1780 : 27,000,000 habitants (📈 +3.8%)
# 1789 : 28,000,000 habitants (📈 +3.7%)
# 1800 : 29,000,000 habitants (📈 +3.6%)
# 1810 : 30,000,000 habitants (📈 +3.4%)
# 1820 : 31,000,000 habitants (📈 +3.3%)
# 1830 : 32,500,000 habitants (📈 +4.8%)
# 1840 : 34,200,000 habitants (📈 +5.2%)
# 1850 : 35,800,000 habitants (📈 +4.7%)
# 1860 : 37,400,000 habitants (📈 +4.5%)
# 1870 : 36,100,000 habitants (📉 -3.5%)
# 1880 : 37,700,000 habitants (📈 +4.4%)
# 1890 : 38,300,000 habitants (📈 +1.6%)
# 1900 : 38,900,000 habitants (📈 +1.6%)
# 1910 : 39,600,000 habitants (📈 +1.8%)
# 1920 : 39,000,000 habitants (📉 -1.5%)
# 1930 : 41,500,000 habitants (📈 +6.4%)
# 1940 : 41,300,000 habitants (📉 -0.5%)
# 1946 : 40,500,000 habitants (📉 -1.9%)
# 1950 : 41,700,000 habitants (📈 +3.0%)
# 1960 : 45,700,000 habitants (📈 +9.6%)
# 1970 : 50,800,000 habitants (📈 +11.2%)
# 1980 : 53,900,000 habitants (📈 +6.1%)
# 1990 : 56,700,000 habitants (📈 +5.2%)
# 2000 : 59,000,000 habitants (📈 +4.1%)
# 2010 : 62,800,000 habitants (📈 +6.4%)
# 2020 : 67,400,000 habitants (📈 +7.3%)

# %%
# Exercice 8 : Identifier les périodes de croissance/déclin

def identifier_tendances(demographie):
    """Identifie les périodes de forte croissance ou de déclin."""
    croissances = []
    declins = []
    
    for i in range(1, len(demographie)):
        annee_prec = int(demographie[i-1]['annee'])
        annee = int(demographie[i]['annee'])
        pop_prec = int(demographie[i-1]['population'])
        pop = int(demographie[i]['population'])
        
        variation = ((pop - pop_prec) / pop_prec) * 100
        periode = f"{annee_prec}-{annee}"
        
        if variation > 20:
            croissances.append((periode, variation))
        elif variation < -5:
            declins.append((periode, variation))
    
    print("📈 Périodes de forte croissance (>20%) :")
    for p, v in croissances:
        print(f"  {p} : +{v:.1f}%")
    
    print("\n📉 Périodes de déclin (<-5%) :")
    for p, v in declins:
        print(f"  {p} : {v:.1f}%")

identifier_tendances(demographie)
# Out:
# 📈 Périodes de forte croissance (>20%) :
#   700-800 : +33.3%
#   1000-1100 : +53.8%
#   1200-1226 : +33.3%
#   1450-1500 : +25.0%
#
# 📉 Périodes de déclin (<-5%) :
#   800-900 : -25.0%
#   1340-1350 : -40.0%
#   1350-1400 : -16.7%

# %% [markdown]
# ---
# # Partie 3 : Utilisation d'APIs historiques
#
# ## 3.1 API Wikidata pour les données historiques

# %%
import requests

# Headers requis par les APIs Wikimedia (évite les erreurs 403 Forbidden)
HEADERS = {
    "User-Agent": "PythonSHS-Training/1.0 (Formation Python pour SHS; Contact: votre@email.com)"
}

def rechercher_personnage_historique(nom):
    """Recherche un personnage historique sur Wikidata."""
    url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbsearchentities",
        "search": nom,
        "language": "fr",
        "format": "json",
        "limit": 5
    }
    
    try:
        response = requests.get(url, params=params, headers=HEADERS)
        response.raise_for_status()
        data = response.json()
        
        resultats = data.get('search', [])
        print(f"Résultats pour '{nom}' :")
        for r in resultats:
            print(f"  - {r.get('label', 'N/A')} : {r.get('description', 'Pas de description')}")
        
        return resultats
        
    except requests.exceptions.RequestException as e:
        print(f"Erreur : {e}")
        return []

# Rechercher Napoléon
rechercher_personnage_historique("Napoléon Bonaparte")
# Out:
# Résultats pour 'Napoléon Bonaparte' :
#   - Napoleon : French military leader, French Emperor 1804–1814 and again in 1815 (1769–1821)
#   - Napoleon Bonaparte : French cruiseferry built in 1996
#   - Napoléon Bonaparte : 1935 film by Abel Gance
#   - Napoleon Bonaparte : painting by Henri Félix Emmanuel Philippoteaux
#   - Napoléon : fictional character from the Fate franchise
# [{'id': 'Q517',
#   'title': 'Q517',
#   'pageid': 776,
#   'concepturi': 'http://www.wikidata.org/entity/Q517',
#   'repository': 'wikidata',
#   'url': '//www.wikidata.org/wiki/Q517',
#   'display': {'label': {'value': 'Napoleon', 'language': 'en'},
#    'description': {'value': 'French military leader, French Emperor 1804–1814 and again in 1815 (1769–1821)',
#     'language': 'en'}},
#   'label': 'Napoleon',
#   'description': 'French military leader, French Emperor 1804–1814 and again in 1815 (1769–1821)',
#   'match': {'type': 'alias', 'language': 'fr', 'text': 'Napoléon Bonaparte'},
#   'aliases': ['Napoléon Bonaparte']},
#  {'id': 'Q3335927',
#   'title': 'Q3335927',
#   'pageid': 3180306,
#   'concepturi': 'http://www.wikidata.org/entity/Q3335927',
#   'repository': 'wikidata',
#   'url': '//www.wikidata.org/wiki/Q3335927',
#   'display': {'label': {'value': 'Napoleon Bonaparte', 'language': 'en'},
#    'description': {'value': 'French cruiseferry built in 1996',
#     'language': 'en'}},
#   'label': 'Napoleon Bonaparte',
#   'description': 'French cruiseferry built in 1996',
#   'match': {'type': 'label', 'language': 'fr', 'text': 'Napoléon Bonaparte'},
#   'aliases': ['Napoléon Bonaparte']},
#  {'id': 'Q21979602',
#   'title': 'Q21979602',
#   'pageid': 24011569,
#   'concepturi': 'http://www.wikidata.org/entity/Q21979602',
#   'repository': 'wikidata',
#   'url': '//www.wikidata.org/wiki/Q21979602',
#   'display': {'label': {'value': 'Napoléon Bonaparte', 'language': 'fr'},
#    'description': {'value': '1935 film by Abel Gance', 'language': 'en'}},
#   'label': 'Napoléon Bonaparte',
#   'description': '1935 film by Abel Gance',
#   'match': {'type': 'label', 'language': 'fr', 'text': 'Napoléon Bonaparte'}},
#  {'id': 'Q65178161',
#   'title': 'Q65178161',
#   'pageid': 64818376,
#   'concepturi': 'http://www.wikidata.org/entity/Q65178161',
#   'repository': 'wikidata',
#   'url': '//www.wikidata.org/wiki/Q65178161',
#   'display': {'label': {'value': 'Napoleon Bonaparte', 'language': 'en'},
#    'description': {'value': 'painting by Henri Félix Emmanuel Philippoteaux',
#     'language': 'en'}},
#   'label': 'Napoleon Bonaparte',
#   'description': 'painting by Henri Félix Emmanuel Philippoteaux',
#   'match': {'type': 'label', 'language': 'fr', 'text': 'Napoléon Bonaparte'},
#   'aliases': ['Napoléon Bonaparte']},
#  {'id': 'Q105889120',
#   'title': 'Q105889120',
#   'pageid': 101240601,
#   'concepturi': 'http://www.wikidata.org/entity/Q105889120',
#   'repository': 'wikidata',
#   'url': '//www.wikidata.org/wiki/Q105889120',
#   'display': {'label': {'value': 'Napoléon', 'language': 'en'},
#    'description': {'value': 'fictional character from the Fate franchise',
#     'language': 'en'}},
#   'label': 'Napoléon',
#   'description': 'fictional character from the Fate franchise',
#   'match': {'type': 'alias', 'language': 'fr', 'text': 'Napoléon Bonaparte'},
#   'aliases': ['Napoléon Bonaparte']}]

# %%
# Exercice 9 : Récupérer les détails d'une entité Wikidata

def obtenir_details_entite(entity_id):
    """Obtient les détails d'une entité Wikidata."""
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{entity_id}.json"
    
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        data = response.json()
        
        entite = data['entities'][entity_id]
        
        # Extraire les informations de base
        labels = entite.get('labels', {})
        descriptions = entite.get('descriptions', {})
        
        nom_fr = labels.get('fr', {}).get('value', 'N/A')
        desc_fr = descriptions.get('fr', {}).get('value', 'N/A')
        
        print(f"📌 {nom_fr}")
        print(f"   {desc_fr}")
        
        return entite
        
    except requests.exceptions.RequestException as e:
        print(f"Erreur : {e}")
        return None

# Napoléon Bonaparte (Q517)
obtenir_details_entite("Q517")
# Out:
# 📌 Napoléon Ier
#    général, Premier consul puis empereur des Français
# {'pageid': 776,
#  'ns': 0,
#  'title': 'Q517',
#  'lastrevid': 2458000162,
#  'modified': '2026-01-26T17:12:53Z',
#  'type': 'item',
#  'id': 'Q517',
#  'labels': {'fr': {'language': 'fr', 'value': 'Napoléon Ier'},
#   'en': {'language': 'en', 'value': 'Napoleon'},
#   'de': {'language': 'de', 'value': 'Napoleon Bonaparte'},
#   'ru': {'language': 'ru', 'value': 'Наполеон I'},
#   'nb': {'language': 'nb', 'value': 'Napoléon Bonaparte'},
#   'it': {'language': 'it', 'value': 'Napoleone Bonaparte'},
#   'ilo': {'language': 'ilo', 'value': 'Napoleon Bonaparte'},
#   'es': {'language': 'es', 'value': 'Napoleón Bonaparte'},
#   'en-ca': {'language': 'en-ca', 'value': 'Napoleon'},
#   'en-gb': {'language': 'en-gb', 'value': 'Napoleon'},
#   'co': {'language': 'co', 'value': 'Napulione Buonaparte'},
#   'nl': {'language': 'nl', 'value': 'Napoleon Bonaparte'},
#   'af': {'language': 'af', 'value': 'Napoléon Bonaparte'},
#   'gsw': {'language': 'gsw', 'value': 'Napoléon Bonaparte'},
#   'am': {'language': 'am', 'value': 'ናፖሌዎን ቦናፓርት'},
#   'an': {'language': 'an', 'value': 'Napolión Bonaparte'},
#   'ang': {'language': 'ang', 'value': 'Napoleon I Francena Cāsere'},
#   'ar': {'language': 'ar', 'value': 'نابليون بونابرت'},
#   'arc': {'language': 'arc', 'value': 'ܢܐܦܠܝܘܢ ܒܘܢܐܦܪܛ'},
#   'arz': {'language': 'arz', 'value': 'نابوليون بونابارت'},
#   'ast': {'language': 'ast', 'value': 'Napoleón Bonaparte'},
#   'az': {'language': 'az', 'value': 'Napoleon Bonapart'},
#   'bar': {'language': 'bar', 'value': 'Napoleon Bonaparte'},
#   'bcl': {'language': 'bcl', 'value': 'Napoleon I'},
#   'be': {'language': 'be', 'value': 'Напалеон I Банапарт'},
#   'bg': {'language': 'bg', 'value': 'Наполеон I'},
#   'bn': {'language': 'bn', 'value': 'নেপোলিয়ন বোনাপার্ট'},
#   'br': {'language': 'br', 'value': 'Napoleon Iañ'},
#   'bs': {'language': 'bs', 'value': 'Napoleón Bonaparte'},
#   'ca': {'language': 'ca', 'value': 'Napoleó Bonaparte'},
#   'ceb': {'language': 'ceb', 'value': 'Napoleon I'},
#   'ckb': {'language': 'ckb', 'value': 'ناپۆلیۆن بۆناپارت'},
#   'cs': {'language': 'cs', 'value': 'Napoleon Bonaparte'},
#   'cv': {'language': 'cv', 'value': 'Наполеон I Бонапарт'},
#   'cy': {'language': 'cy', 'value': 'Napoleon'},
#   'da': {'language': 'da', 'value': 'Napoleon 1. af Frankrig'},
#   'diq': {'language': 'diq', 'value': 'Napoleon I'},
#   'el': {'language': 'el', 'value': 'Ναπολέων Α΄ της Γαλλίας'},
#   'eo': {'language': 'eo', 'value': 'Napoleono Bonaparte'},
#   'et': {'language': 'et', 'value': 'Napoleon I'},
#   'eu': {'language': 'eu', 'value': 'Napoleon Bonaparte'},
#   'ext': {'language': 'ext', 'value': 'Napoleón I de Fráncia'},
#   'fa': {'language': 'fa', 'value': 'ناپلئون بناپارت'},
#   'fi': {'language': 'fi', 'value': 'Napoleon I'},
#   'fo': {'language': 'fo', 'value': 'Napoleon Bonaparte'},
#   'fur': {'language': 'fur', 'value': 'Napoleon Bonaparte'},
#   'fy': {'language': 'fy', 'value': 'Napoleon Bonaparte'},
#   'ga': {'language': 'ga', 'value': 'Napoléon Bonaparte'},
#   'gan': {'language': 'gan', 'value': '拿破崙'},
#   'gd': {'language': 'gd', 'value': 'Napoleon Bonaparte'},
#   'gl': {'language': 'gl', 'value': 'Napoleón I de Francia'},
#   'hak': {'language': 'hak', 'value': 'Nâ-pho-lùn yit-sṳ'},
#   'he': {'language': 'he', 'value': 'נפוליאון בונפרטה'},
#   'hi': {'language': 'hi', 'value': 'नेपोलियन बोनापार्ट'},
#   'hif': {'language': 'hif', 'value': 'Napoleon I of France'},
#   'hr': {'language': 'hr', 'value': 'Napoleon Bonaparte'},
#   'hu': {'language': 'hu', 'value': 'I. Napóleon'},
#   'hy': {'language': 'hy', 'value': 'Նապոլեոն Բոնապարտ'},
#   'ia': {'language': 'ia', 'value': 'Napoléon Bonaparte'},
#   'id': {'language': 'id', 'value': 'Napoleon'},
#   'io': {'language': 'io', 'value': 'Napoléon 1ma'},
#   'is': {'language': 'is', 'value': 'Napóleon Bónaparte'},
#   'ja': {'language': 'ja', 'value': 'ナポレオン・ボナパルト'},
#   'jbo': {'language': 'jbo', 'value': 'napoleon'},
#   'jv': {'language': 'jv', 'value': 'Napoléon Bonaparte'},
#   'ka': {'language': 'ka', 'value': 'ნაპოლეონ ბონაპარტი'},
#   'kaa': {'language': 'kaa', 'value': 'Napoleon I Bonapart'},
#   'kk': {'language': 'kk', 'value': 'Наполеон Бонапарт'},
#   'km': {'language': 'km', 'value': 'ណាប៉ូលេអុងបូណាប៉ារត៍'},
#   'kn': {'language': 'kn', 'value': 'ನೆಪೋಲಿಯನ್ ಬೋನಪಾರ್ತ್'},
#   'ko': {'language': 'ko', 'value': '나폴레옹 보나파르트'},
#   'ksh': {'language': 'ksh', 'value': 'Napoléon Bonaparte'},
#   'ku': {'language': 'ku', 'value': 'Napoleon Bonaparte'},
#   'ky': {'language': 'ky', 'value': 'Наполеон Бонапарт'},
#   'la': {'language': 'la', 'value': 'Napoleo I'},
#   'lb': {'language': 'lb', 'value': 'Napoléon Bonaparte'},
#   'lez': {'language': 'lez', 'value': 'I Наполеон Бонапарт'},
#   'lg': {'language': 'lg', 'value': 'Napooleon Bonapat'},
#   'lij': {'language': 'lij', 'value': 'Napolion Bonaparte'},
#   'lmo': {'language': 'lmo', 'value': 'Napoleon Bonapart'},
#   'lt': {'language': 'lt', 'value': 'Napoleonas Bonapartas'},
#   'lv': {'language': 'lv', 'value': 'Napoleons Bonaparts'},
#   'mk': {'language': 'mk', 'value': 'Наполеон Бонапарт'},
#   'ml': {'language': 'ml', 'value': 'നെപ്പോളിയൻ ബോണപ്പാർട്ട്'},
#   'mn': {'language': 'mn', 'value': 'Наполеон I Бонапарт'},
#   'mr': {'language': 'mr', 'value': 'नेपोलियन बोनापार्ट'},
#   'ms': {'language': 'ms', 'value': 'Napoleon Bonaparte'},
#   'mt': {'language': 'mt', 'value': "Napuljun I ta' Franza"},
#   'my': {'language': 'my', 'value': 'နပိုလီယန်'},
#   'mzn': {'language': 'mzn', 'value': 'ناپلئون'},
#   'nap': {'language': 'nap', 'value': 'Napoleone Bonaparte'},
#   'nds': {'language': 'nds', 'value': 'Napoléon Bonaparte'},
#   'nds-nl': {'language': 'nds-nl', 'value': 'Napoleon Bonaparte'},
#   'ne': {'language': 'ne', 'value': 'नेपोलियन बोनापार्ट'},
#   'nn': {'language': 'nn', 'value': 'Napoléon Bonaparte'},
#   'oc': {'language': 'oc', 'value': 'Napoleon Bonaparte'},
#   'pl': {'language': 'pl', 'value': 'Napoleon Bonaparte'},
#   'pms': {'language': 'pms', 'value': 'Napoleon Bon-a-part'},
#   'pnb': {'language': 'pnb', 'value': 'نیپولین'},
#   'ps': {'language': 'ps', 'value': 'ناپليون بوناپارت'},
#   'pt': {'language': 'pt', 'value': 'Napoleão Bonaparte'},
#   'qu': {'language': 'qu', 'value': 'Napoléon Bonaparte'},
#   'rm': {'language': 'rm', 'value': 'Napoleun Bonaparte'},
#   'ro': {'language': 'ro', 'value': 'Napoleon I'},
#   'rue': {'language': 'rue', 'value': 'Наполеон І'},
#   'sa': {'language': 'sa', 'value': 'नेपोलियन बोनापार्ट'},
#   'scn': {'language': 'scn', 'value': 'Napuliuni Bonaparti'},
#   'sco': {'language': 'sco', 'value': 'Napoleon I'},
#   'sh': {'language': 'sh', 'value': 'Napoleon Bonaparte'},
#   'sk': {'language': 'sk', 'value': 'Napoleon Bonaparte'},
#   'sl': {'language': 'sl', 'value': 'Napoleon Bonaparte'},
#   'sq': {'language': 'sq', 'value': 'Napoleon Bonaparte'},
#   'sr': {'language': 'sr', 'value': 'Наполеон I Бонапарта'},
#   'stq': {'language': 'stq', 'value': 'Napoleon Bonaparte'},
#   'su': {'language': 'su', 'value': 'Napoleon Bonaparte'},
#   'sv': {'language': 'sv', 'value': 'Napoleon I'},
#   'sw': {'language': 'sw', 'value': 'Napoleon Bonaparte'},
#   'szl': {'language': 'szl', 'value': 'Napoleůn Bůnaparte'},
#   'ta': {'language': 'ta', 'value': 'பிரான்சின் முதலாம் நெப்போலியன்'},
#   'te': {'language': 'te', 'value': 'నెపోలియన్'},
#   'th': {'language': 'th', 'value': 'จักรพรรดินโปเลียนที่ 1'},
#   'tl': {'language': 'tl', 'value': 'Napoleon I ng Pransya'},
#   'tr': {'language': 'tr', 'value': 'Napolyon Bonapart'},
#   'tt': {'language': 'tt', 'value': 'Наполеон Бонапарт'},
#   'udm': {'language': 'udm', 'value': 'Наполеон'},
#   'ug': {'language': 'ug', 'value': 'ﻧﺎﭘﻮﻟﯧﺌﻮﻥ ﺑﻮﻧﺎﭘﺎﺭﺕ'},
#   'uk': {'language': 'uk', 'value': 'Наполеон I Бонапарт'},
#   'ur': {'language': 'ur', 'value': 'نپولین'},
#   'uz': {'language': 'uz', 'value': 'Napoleon I'},
#   'vec': {'language': 'vec', 'value': 'Napoleon Bonaparte'},
#   'vi': {'language': 'vi', 'value': 'Napoléon Bonaparte'},
#   'vls': {'language': 'vls', 'value': 'Napoleong'},
#   'wa': {'language': 'wa', 'value': 'Napoleyon Bonapåre'},
#   'war': {'language': 'war', 'value': 'Napoleon'},
#   'xmf': {'language': 'xmf', 'value': 'ნაპოლეონ ბონაპარტი'},
#   'yi': {'language': 'yi', 'value': 'נאפאלעאן באנאפארטע'},
#   'yo': {'language': 'yo', 'value': 'Napoleon Bonaparte'},
#   'zh': {'language': 'zh', 'value': '拿破崙'},
#   'yue': {'language': 'yue', 'value': '拿破崙'},
#   'de-ch': {'language': 'de-ch', 'value': 'Napoleon Bonaparte'},
#   'so': {'language': 'so', 'value': 'Napoleon Bonaparte'},
#   'ba': {'language': 'ba', 'value': 'Наполеон I Бонапарт'},
#   'li': {'language': 'li', 'value': 'Napoleon'},
#   'mg': {'language': 'mg', 'value': 'Napoleon'},
#   'ce': {'language': 'ce', 'value': 'Наполеон I'},
#   'ace': {'language': 'ace', 'value': 'Napolèon Bonaparté'},
#   'sgs': {'language': 'sgs', 'value': 'Napaleuons'},
#   'nan': {'language': 'nan', 'value': 'Napoléon 1-sè'},
#   'lzh': {'language': 'lzh', 'value': '拿破崙一世'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'Напалеон I Банапарт'},
#   'vro': {'language': 'vro', 'value': 'Napoleon I'},
#   'bxr': {'language': 'bxr', 'value': 'Наполеон Бонапарт'},
#   'lo': {'language': 'lo', 'value': 'ຈັກກະພັດນາໂປເລອົງທີ 1'},
#   'sah': {'language': 'sah', 'value': 'Наполеон'},
#   'sc': {'language': 'sc', 'value': 'Napoleone Bonaparte'},
#   'tw': {'language': 'tw', 'value': 'Napoléon Bonaparte'},
#   'eml': {'language': 'eml', 'value': 'Napulèòṅ'},
#   'cbk-zam': {'language': 'cbk-zam', 'value': 'Napoleon'},
#   'sm': {'language': 'sm', 'value': 'Napoelon'},
#   'na': {'language': 'na', 'value': 'Napoleon Bonaparte'},
#   'ny': {'language': 'ny', 'value': 'Napoleon'},
#   'ki': {'language': 'ki', 'value': 'Napoleon'},
#   'ti': {'language': 'ti', 'value': 'ናፖሌዎን ቦናፓርት'},
#   'kk-kz': {'language': 'kk-kz', 'value': 'Наполеон I'},
#   'cdo': {'language': 'cdo', 'value': 'Napoléon Bonaparte'},
#   'ht': {'language': 'ht', 'value': 'Napoléon Bonaparte'},
#   'kab': {'language': 'kab', 'value': 'Napoleon'},
#   'gu': {'language': 'gu', 'value': 'નેપોલિયન બોનાપાર્ટ'},
#   'zea': {'language': 'zea', 'value': 'Napoleon'},
#   'wuu': {'language': 'wuu', 'value': '拿破崙一世'},
#   'ts': {'language': 'ts', 'value': 'Napoleon'},
#   'kbd': {'language': 'kbd', 'value': 'Наполеон I'},
#   'om': {'language': 'om', 'value': 'Napoleon'},
#   'tyv': {'language': 'tyv', 'value': 'Наполеон I'},
#   'as': {'language': 'as', 'value': 'নেপোলিয়ন'},
#   'mai': {'language': 'mai', 'value': 'नेपोलियन बोनापार्ट'},
#   'ee': {'language': 'ee', 'value': 'Napoleon Bonaparte'},
#   'chr': {'language': 'chr', 'value': 'Napoleon'},
#   'or': {'language': 'or', 'value': 'ନେପୋଲିୟନ ବୋନାପାର୍ଟ'},
#   'pa': {'language': 'pa', 'value': 'ਨਪੋਲੀਅਨ'},
#   'zh-cn': {'language': 'zh-cn', 'value': '拿破仑'},
#   'zh-hans': {'language': 'zh-hans', 'value': '拿破仑'},
#   'zh-hant': {'language': 'zh-hant', 'value': '拿破崙'},
#   'zh-hk': {'language': 'zh-hk', 'value': '拿破崙'},
#   'zh-mo': {'language': 'zh-mo', 'value': '拿破崙'},
#   'zh-my': {'language': 'zh-my', 'value': '拿破仑'},
#   'zh-sg': {'language': 'zh-sg', 'value': '拿破仑'},
#   'zh-tw': {'language': 'zh-tw', 'value': '拿破崙'},
#   'lrc': {'language': 'lrc', 'value': 'ناپئلون بئناپارت'},
#   'jam': {'language': 'jam', 'value': 'Napuolian I a Frans'},
#   'olo': {'language': 'olo', 'value': 'Napoleon I'},
#   'frr': {'language': 'frr', 'value': 'Napoleon Bonaparte'},
#   'azb': {'language': 'azb', 'value': 'ناپلئون بوناپارت'},
#   'mwl': {'language': 'mwl', 'value': 'Napoleon Bonaparte'},
#   'dty': {'language': 'dty', 'value': 'नेपोलियन बोनापार्ट'},
#   'vep': {'language': 'vep', 'value': 'Napoleon I Bonapart'},
#   'qug': {'language': 'qug', 'value': 'Napolion Bionapartein'},
#   'kbp': {'language': 'kbp', 'value': 'Napoléon Bonaparte'},
#   'ab': {'language': 'ab', 'value': 'Наполеон Бонапарт'},
#   'ha': {'language': 'ha', 'value': 'Napoleon'},
#   'lad': {'language': 'lad', 'value': 'Napoleon'},
#   'lfn': {'language': 'lfn', 'value': 'Napoleon Bonaparte'},
#   'sd': {'language': 'sd', 'value': 'نيپولين'},
#   'sat': {'language': 'sat', 'value': 'ᱱᱮᱯᱳᱞᱤᱭᱚᱱ ᱵᱳᱱᱟᱯᱟᱨᱴ'},
#   'pcd': {'language': 'pcd', 'value': 'Napoléon Ier'},
#   'bho': {'language': 'bho', 'value': 'नेपोलियन'},
#   'ltg': {'language': 'ltg', 'value': 'Napoļeons Bonaparts'},
#   'shn': {'language': 'shn', 'value': 'ၼပူဝ်းလီးယၼ်း'},
#   'gcr': {'language': 'gcr', 'value': 'Napoléon Ié'},
#   'frp': {'language': 'frp', 'value': 'Napoléon Iér'},
#   'mi': {'language': 'mi', 'value': 'Nepōriana'},
#   'nqo': {'language': 'nqo', 'value': 'ߣߊ߲ߔߏߟߌߦߏ߲߫'},
#   'lld': {'language': 'lld', 'value': 'Napoleon'},
#   'ary': {'language': 'ary', 'value': 'ناپوليون بوناپارت'},
#   'crh': {'language': 'crh', 'value': 'I Napoleon'},
#   'pam': {'language': 'pam', 'value': 'Napoléon Bonaparte'},
#   'pap': {'language': 'pap', 'value': 'Napoleon Bonaparte'},
#   'ban': {'language': 'ban', 'value': 'Napoléon'},
#   'gn': {'language': 'gn', 'value': 'Napoleón Bonaparte'},
#   'kw': {'language': 'kw', 'value': 'Napoleon Ia a Bow Frynk'},
#   'av': {'language': 'av', 'value': 'Наполеон'},
#   'za': {'language': 'za', 'value': 'Nazbolunz'},
#   'awa': {'language': 'awa', 'value': 'नेपोलियन बोनापार्ट'},
#   'hyw': {'language': 'hyw', 'value': 'Նափոլէոն Պոնափարթ'},
#   'anp': {'language': 'anp', 'value': 'नेपोलियन बोनापार्ट'},
#   'rki': {'language': 'rki', 'value': 'နပိုလီယန်'},
#   'szy': {'language': 'szy', 'value': 'Na-pu-lun-sakacacay'},
#   'gv': {'language': 'gv', 'value': 'Napoléon'},
#   'bew': {'language': 'bew', 'value': 'Napoléon Bonaparte'},
#   'btm': {'language': 'btm', 'value': 'Napoleon Bonaparte'},
#   'bm': {'language': 'bm', 'value': 'Napoléon Ier'},
#   'pcm': {'language': 'pcm', 'value': 'Napoleon'},
#   'bjn': {'language': 'bjn', 'value': 'Napoleon Bonaparte'},
#   'ann': {'language': 'ann', 'value': 'Napoleon Bonaparte'},
#   'gor': {'language': 'gor', 'value': 'Napoleon Bonaparte'},
#   'iba': {'language': 'iba', 'value': 'Napoleon'},
#   'si': {'language': 'si', 'value': 'නැපෝලියන් බොනපාට්'},
#   'tok': {'language': 'tok', 'value': 'jan Napolejon Ponapa'},
#   'mul': {'language': 'mul', 'value': 'Napoléon Bonaparte'},
#   'tly': {'language': 'tly', 'value': 'Napoleon I'},
#   'mad': {'language': 'mad', 'value': 'Napoleon Bonaparte'},
#   'knc': {'language': 'knc', 'value': 'Napoleon'},
#   'pt-br': {'language': 'pt-br', 'value': 'Napoleon Bonaparte'},
#   'rn': {'language': 'rn', 'value': 'Napoléyoni'},
#   'zu': {'language': 'zu', 'value': 'Napoleon'},
#   'new': {'language': 'new', 'value': 'नेपोलियन बोनापार्ट'}},
#  'descriptions': {'fr': {'language': 'fr',
#    'value': 'général, Premier consul puis empereur des Français'},
#   'de': {'language': 'de',
#    'value': 'französischer General, Staatsmann und Kaiser'},
#   'nb': {'language': 'nb',
#    'value': 'fransk militær kommandant og politisk leder.'},
#   'en': {'language': 'en',
#    'value': 'French military leader, French Emperor 1804–1814 and again in 1815 (1769–1821)'},
#   'it': {'language': 'it',
#    'value': 'politico e generale francese (1769–1821), primo console (1799–1804) e imperatore (r. 1804–1815) di Francia'},
#   'ilo': {'language': 'ilo',
#    'value': 'Pranses a milisia ken daulo ti politika'},
#   'es': {'language': 'es', 'value': 'político y militar francés'},
#   'ru': {'language': 'ru',
#    'value': 'император французов, полководец и государственный деятель'},
#   'el': {'language': 'el',
#    'value': 'Γάλλος μονάρχης, στρατιωτικός και πολιτικός'},
#   'hu': {'language': 'hu',
#    'value': 'francia tábornok, hadvezér, politikus, császár'},
#   'pl': {'language': 'pl',
#    'value': 'francuski monarcha, początkowo dowódca wojskowy'},
#   'zh-hans': {'language': 'zh-hans', 'value': '法国军事家与政治家'},
#   'nl': {'language': 'nl',
#    'value': 'Frans militair en politiek leider, keizer der Fransen van 1804 tot 1815 (1769–1821)'},
#   'uk': {'language': 'uk',
#    'value': 'французький імператор у 1804–1814 і 1815'},
#   'scn': {'language': 'scn',
#    'value': 'monarca, capu militari e pulìticu francisi'},
#   'bs': {'language': 'bs',
#    'value': 'francuski monarh, vojskovođa i političar'},
#   'kk': {'language': 'kk',
#    'value': 'Франция императоры, атақты қолбасшы және мемлекеттік қайраткер'},
#   'gl': {'language': 'gl', 'value': 'emperador de Francia'},
#   'fa': {'language': 'fa',
#    'value': 'رهبر نظامی، سیاستمدار و نخستین امپراتور فرانسه (۱۸۰۴–۱۸۱۵)'},
#   'nds': {'language': 'nds',
#    'value': 'Französche Militär- un Politikföhrer, Kaiser'},
#   'ml': {'language': 'ml', 'value': 'ഫ്രഞ്ച് ചക്രവർത്തി'},
#   'zh': {'language': 'zh', 'value': '法國軍事家與政治家'},
#   'zh-cn': {'language': 'zh-cn', 'value': '法国军事家与政治家'},
#   'zh-hant': {'language': 'zh-hant', 'value': '法國軍事家與政治家'},
#   'zh-hk': {'language': 'zh-hk', 'value': '法國軍事家與政治家'},
#   'zh-mo': {'language': 'zh-mo', 'value': '法國軍事家與政治家'},
#   'zh-my': {'language': 'zh-my', 'value': '法国军事家与政治家'},
#   'zh-sg': {'language': 'zh-sg', 'value': '法国军事家与政治家'},
#   'zh-tw': {'language': 'zh-tw', 'value': '法國軍事家與政治家'},
#   'br': {'language': 'br', 'value': "penn-ar-stad Bro-c'hall"},
#   'sv': {'language': 'sv',
#    'value': 'kejsare av Frankrike 1804–1814 och mars–juni 1815'},
#   'fi': {'language': 'fi',
#    'value': 'Ranskan keisari vuosina 1804–1814 ja 1815 (1769–1821)'},
#   'vi': {'language': 'vi',
#    'value': 'hoàng đế và nhà chỉ huy quân sự người Pháp (1769–1821)'},
#   'id': {'language': 'id',
#    'value': 'Jenderal Prancis, Kaisar Prancis (memerintah 1804–1814, 1815)'},
#   'lv': {'language': 'lv', 'value': 'Franču valdnieks un karavadonis'},
#   'ko': {'language': 'ko', 'value': '프랑스 제1제국의 초대 황제 (1769~1821)'},
#   'he': {'language': 'he',
#    'value': 'מצביא ומייסד הקיסרות הראשונה של צרפת, שליט צרפת בתחילת המאה ה-19'},
#   'bn': {'language': 'bn',
#    'value': 'ফরাসি সমরনেতা, রাজনীতিবিদ ও সম্রাট (১৭৬৯-১৮২১)'},
#   'yue': {'language': 'yue', 'value': '法國軍人同政治人'},
#   'ar': {'language': 'ar', 'value': 'قائد عسكري وإمبراطور فرنسي'},
#   'pa': {'language': 'pa', 'value': 'ਫਰਾਂਸੀਸੀ ਬਾਦਸ਼ਾਹ, ਫੌਜੀ ਅਤੇ ਸਿਆਸੀ ਆਗੂ'},
#   'sr': {'language': 'sr',
#    'value': 'француски монарх, војсковођа и политичар'},
#   'sk': {'language': 'sk', 'value': 'francúzsky generál a politický vodca'},
#   'pt': {'language': 'pt', 'value': 'Imperador da França (1804–1814, – 1815)'},
#   'en-gb': {'language': 'en-gb',
#    'value': 'French general, First Consul and later Emperor of the French'},
#   'hy': {'language': 'hy',
#    'value': 'ֆրանսիացի ռազմական և քաղաքական գործիչ, Ֆրանսիայի կայսր'},
#   'lt': {'language': 'lt', 'value': 'Prancūzijos imperatorius ir karvedys'},
#   'cs': {'language': 'cs', 'value': 'francouzský vojevůdce a císař'},
#   'bg': {'language': 'bg', 'value': 'император на Франция'},
#   'kn': {'language': 'kn', 'value': 'ಫ್ರಾನ್ಸ್ ನೇತಾರ ಮತ್ತು ಆಡಳಿತಗಾರ'},
#   'ja': {'language': 'ja', 'value': 'フランスの軍人、革命家、第一帝政期のフランス皇帝'},
#   'nqo': {'language': 'nqo', 'value': 'ߝߊ߬ߙߊ߲߬ߛߌ߫ ߞߟߍ߬ߕߌ߮ ߣߴߊ߬ ߡߊ߲߬ߛߊ'},
#   'tr': {'language': 'tr', 'value': 'Fransız asker ve imparator (1769–1821)'},
#   'eo': {'language': 'eo', 'value': 'franca generalo kaj imperiestro'},
#   'or': {'language': 'or',
#    'value': 'ନେପୋଲିୟନ୍ ଶତ୍ରୁ ମାନଙ୍କୁ 1792 ସେପଟେମ୍ବର 20 ରେ ପରାସ୍ତ କଲେ। ବିପ୍ଳବୀ ମାନେ ଉକ୍ତ ଦିନ ଏକ national convention ତିଆରି କଲେ।'},
#   'ro': {'language': 'ro',
#    'value': 'lider militar francez, Împărat Francez 1804–1814 și din nou în 1815'},
#   'ca': {'language': 'ca', 'value': 'militar i emperador de França'},
#   'pap': {'language': 'pap', 'value': 'general i politiko franses'},
#   'mr': {'language': 'mr', 'value': 'फ्रान्सचा शूर योद्धा व सम्राट'},
#   'is': {'language': 'is',
#    'value': 'franskur hershöfðingi og keisari (1769-1821)'},
#   'az': {'language': 'az',
#    'value': 'Fransa imperatoru, bacarıqlı sərkərdə, Fransa inqilabi ordusunun Generalı'},
#   'gn': {'language': 'gn', 'value': 'ojokuaikuaáva ha ñorairõhára ruvicha'},
#   'hi': {'language': 'hi',
#    'value': 'फ्रांस देश के भूतपूर्व सम्राट (शासनकालः 1804-1814, 1815)'},
#   'ckb': {'language': 'ckb',
#    'value': 'ژەنەڕاڵ و ئیمپڕاتۆری فەڕەنسی (١٧٦٩–١٨٢١)'},
#   'tw': {'language': 'tw', 'value': 'Amanyɔni'},
#   'av': {'language': 'av',
#    'value': 'Паранс рагъулав цевехъан, парансазул император 1804–1814 ва цӀидасан 1815 соназда'},
#   'ga': {'language': 'ga',
#    'value': 'ceannaire míleata Francach, agus Impire na Fraince 1804–1814 agus 1815'},
#   'ast': {'language': 'ast',
#    'value': 'políticu y militar francés (1769–1821)'},
#   'sd': {'language': 'sd',
#    'value': 'فوجي اڳواڻ ۽ فرانس جو شهنشاهه (1769-1821)'},
#   'cy': {'language': 'cy',
#    'value': 'arweinydd milwrol Ffrainc, Ymerawdwr Ffrainc 1804–1814 ac eto ym 1815 (1769-1821)'},
#   'io': {'language': 'io', 'value': 'imperiestro di Francia'},
#   'gcr': {'language': 'gcr',
#    'value': "roun militèr, gjénéral annan larmé di Pronmyé Répiblik franséz, né di Révolisyon-an, koumandan an chèf di larmé d'Itali épi di larmé d'Oryan"},
#   'af': {'language': 'af',
#    'value': 'Franse militêre leier, Franse keiser 1804–1814 en weer in 1815'},
#   'eu': {'language': 'eu',
#    'value': 'korsikar jatorriko jeneral eta estatu-gizon frantsesa'},
#   'gv': {'language': 'gv',
#    'value': 'toshiagh caggee Frangagh as Impir ny Frangee'},
#   'sl': {'language': 'sl',
#    'value': 'francoski vojskovodja, francoski cesar v letih 1804–1814 in 1815'},
#   'lb': {'language': 'lb', 'value': 'franséische Generol a Keeser'},
#   'be': {'language': 'be',
#    'value': 'палкаводзец, імператар Францыі (1804—1814, 1815)'},
#   'pcm': {'language': 'pcm',
#    'value': 'French military leader, French Emperor 1804–1814 and again in 1815'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'францускі імпэратар'},
#   'tok': {'language': 'tok', 'value': 'jan li lawa e ma Kanse'},
#   'rue': {'language': 'rue',
#    'value': 'французскый державный, політичный і воєнный дїятель, войвода, первый конзул Французкої Републикы'},
#   'ne': {'language': 'ne', 'value': 'फ्रान्सेली सम्राट'},
#   'pt-br': {'language': 'pt-br',
#    'value': 'Imperador da França (1804–1814, – 1815) e militar francês'}},
#  'aliases': {'en': [{'language': 'en', 'value': 'Napoléon Bonaparte'},
#    {'language': 'en', 'value': 'Napoleone di Buonaparte'},
#    {'language': 'en', 'value': 'Empereur des Français Napoléon I'},
#    {'language': 'en', 'value': 'Napoleon Buonaparte'},
#    {'language': 'en', 'value': 'Napoleone Bonaparte'},
#    {'language': 'en', 'value': 'Napoleone Buonaparte'},
#    {'language': 'en', 'value': 'Napoleon I'},
#    {'language': 'en', 'value': 'the Corsican Napolean'},
#    {'language': 'en', 'value': 'The Little Corporal'},
#    {'language': 'en', 'value': 'Napulione Buonaparte'},
#    {'language': 'en', 'value': 'Napulione di Buonaparte'},
#    {'language': 'en', 'value': 'Napoleon I of France'},
#    {'language': 'en', 'value': 'Napoleone I'},
#    {'language': 'en', 'value': 'Little Corporal'},
#    {'language': 'en', 'value': 'Emperador dels Francesos Napoleó I'},
#    {'language': 'en', 'value': 'Napoleon Bonaparte'}],
#   'de': [{'language': 'de', 'value': 'Napoleon'},
#    {'language': 'de', 'value': 'Napoleone Buonaparte'},
#    {'language': 'de', 'value': 'Napoleon I.'},
#    {'language': 'de', 'value': 'Napoléon Bonaparte'},
#    {'language': 'de', 'value': 'Napoleone I'}],
#   'ru': [{'language': 'ru', 'value': 'Наполеон Бонапарт'},
#    {'language': 'ru', 'value': 'Наполеон I Бонапарт'},
#    {'language': 'ru', 'value': 'Бонапарт, Наполеон'},
#    {'language': 'ru', 'value': 'Бонапарт'},
#    {'language': 'ru', 'value': 'Император Наполеон'},
#    {'language': 'ru', 'value': 'Маленький капрал'}],
#   'fr': [{'language': 'fr', 'value': 'Napoléon Bonaparte'},
#    {'language': 'fr', 'value': 'Bonaparte'},
#    {'language': 'fr', 'value': 'Napoléon'},
#    {'language': 'fr', 'value': 'Buonaparte'},
#    {'language': 'fr', 'value': 'Napoleone di Buonaparte'},
#    {'language': 'fr', 'value': 'Napoléon I'},
#    {'language': 'fr', 'value': 'Napoleone I'},
#    {'language': 'fr', 'value': 'Napoleone Buonaparte'}],
#   'es': [{'language': 'es', 'value': 'Napoleon Bonaparte'},
#    {'language': 'es', 'value': 'Napoleon I Bonaparte'},
#    {'language': 'es', 'value': 'Napoleon The Mega Tall'},
#    {'language': 'es', 'value': 'The Gamer'},
#    {'language': 'es', 'value': 'Napoleón I Bonaparte'},
#    {'language': 'es', 'value': 'Napoleone I'},
#    {'language': 'es', 'value': 'Emperador de Francia Napoleón I'}],
#   'el': [{'language': 'el', 'value': 'Ναπολέον'},
#    {'language': 'el', 'value': 'Βοναπάρτης'},
#    {'language': 'el', 'value': 'Ναπολέων Βοναπάρτης'},
#    {'language': 'el', 'value': 'Ναπολέων'},
#    {'language': 'el', 'value': 'Μέγας Ναπολέων'},
#    {'language': 'el', 'value': "Ναπολέων Α' της Γαλλίας"},
#    {'language': 'el', 'value': 'Ναπολέοντας Βοναπάρτης'},
#    {'language': 'el', 'value': "Ναπολέων Α'"}],
#   'hu': [{'language': 'hu', 'value': 'Bonaparte Napóleon'}],
#   'he': [{'language': 'he', 'value': 'נפוליאון'},
#    {'language': 'he', 'value': 'נפוליון'},
#    {'language': 'he', 'value': 'נפוליון בונפרטה'},
#    {'language': 'he', 'value': 'נפוליאון בונפארטה'},
#    {'language': 'he', 'value': 'נפוליאון בונאפארטה'},
#    {'language': 'he', 'value': 'נפוליון בונפארטה'}],
#   'nl': [{'language': 'nl', 'value': 'Napoleon I'},
#    {'language': 'nl', 'value': 'keizer Napoleon I'},
#    {'language': 'nl', 'value': 'Napoléon Bonaparte'},
#    {'language': 'nl', 'value': 'N. Bonaparte'},
#    {'language': 'nl', 'value': 'Napoleone I'}],
#   'bs': [{'language': 'bs', 'value': 'Napoleón'},
#    {'language': 'bs', 'value': 'Napoleon'},
#    {'language': 'bs', 'value': 'Napoleon Bonaparte'},
#    {'language': 'bs', 'value': 'Napoléon Bonaparte'}],
#   'gl': [{'language': 'gl', 'value': 'Napoleone di Bouonaparte'},
#    {'language': 'gl', 'value': 'Napoleón Bonaparte'}],
#   'nds': [{'language': 'nds', 'value': 'Napoleone di Buonaparte'},
#    {'language': 'nds', 'value': 'Napoleon I'},
#    {'language': 'nds', 'value': 'Napoleon Bonaparte'}],
#   'cs': [{'language': 'cs', 'value': 'Napoleon'},
#    {'language': 'cs', 'value': 'Napoleon I.'},
#    {'language': 'cs', 'value': 'Napoléon Bonaparte'},
#    {'language': 'cs', 'value': 'Napoleone Buonaparte'}],
#   'br': [{'language': 'br', 'value': 'Napoleon Bonaparte'},
#    {'language': 'br', 'value': 'Bonaparte'},
#    {'language': 'br', 'value': 'Napoleone Buonaparte'}],
#   'uk': [{'language': 'uk', 'value': 'Наполеон I'},
#    {'language': 'uk', 'value': 'Бонапарт'},
#    {'language': 'uk', 'value': 'Наполеон Бонапарт'}],
#   'fi': [{'language': 'fi', 'value': 'Napoléon Bonaparte'},
#    {'language': 'fi', 'value': 'Napoleone Buonaparte'}],
#   'ar': [{'language': 'ar', 'value': 'نابليون بونابارت'},
#    {'language': 'ar', 'value': 'نابليون بونبارت'},
#    {'language': 'ar', 'value': 'نابوليون بونابارت'},
#    {'language': 'ar', 'value': 'نابيلون بونابرت'},
#    {'language': 'ar', 'value': 'نابوليون'},
#    {'language': 'ar', 'value': 'نابوليون بونابرت'},
#    {'language': 'ar', 'value': 'نابوليون بونبارت'},
#    {'language': 'ar', 'value': 'نابوليون الأول'},
#    {'language': 'ar', 'value': 'نابليون'},
#    {'language': 'ar', 'value': 'ناپليون'}],
#   'lb': [{'language': 'lb', 'value': 'Napoleon Bonaparte'}],
#   'cy': [{'language': 'cy', 'value': 'Napoléon Bonaparte'},
#    {'language': 'cy', 'value': 'Napoleone Buonaparte'}],
#   'hy': [{'language': 'hy', 'value': 'Նապոլեոն I Բոնապարտ'},
#    {'language': 'hy', 'value': 'Նապոլեոն I'},
#    {'language': 'hy', 'value': 'Բոնապարտ'}],
#   'zh': [{'language': 'zh', 'value': '拿破崙·波拿巴'},
#    {'language': 'zh', 'value': '拿破崙一世'},
#    {'language': 'zh', 'value': '拿破仑·波拿巴'},
#    {'language': 'zh', 'value': '拿破崙·波拿帕特'}],
#   'it': [{'language': 'it', 'value': 'Napoleone'},
#    {'language': 'it', 'value': 'Napoleone I'},
#    {'language': 'it', 'value': 'Napoleone di Buonaparte'},
#    {'language': 'it',
#     'value': "Napoleone I, per la Grazia di Dio e le Costituzioni, Imperatore de' Francesi e Re d'Italia"},
#    {'language': 'it', 'value': 'Il Piccolo Caporale'},
#    {'language': 'it', 'value': 'Le Petit Caporal'},
#    {'language': 'it', 'value': 'Le Corse'}],
#   'pl': [{'language': 'pl', 'value': 'Napoléon Bonaparte'},
#    {'language': 'pl', 'value': 'Le Petit Caporal'},
#    {'language': 'pl', 'value': 'Le Corse'},
#    {'language': 'pl', 'value': 'Napoleone di Buonaparte'},
#    {'language': 'pl', 'value': 'Napoleon Buonaparte'},
#    {'language': 'pl', 'value': 'Napoleon I'},
#    {'language': 'pl', 'value': 'Emperador de Francia Napoleón I'},
#    {'language': 'pl', 'value': 'emperador dels francesos Napoleó I'},
#    {'language': 'pl', 'value': 'Empereur des Français Napoléon I'}],
#   'da': [{'language': 'da', 'value': 'Napoleon Bonaparte'},
#    {'language': 'da', 'value': 'Napoléon Bonaparte'}],
#   'ko': [{'language': 'ko', 'value': '나폴레옹'}],
#   'nn': [{'language': 'nn', 'value': 'Napoléon I'},
#    {'language': 'nn', 'value': 'Napoleon Bonaparte'}],
#   'nb': [{'language': 'nb', 'value': 'Napoleon Bonaparte'}],
#   'nqo': [{'language': 'nqo', 'value': 'ߣߊ߲ߔߏߟߌߦߏ߲߫ ߓߐߣߔߊߙߕ'}],
#   'co': [{'language': 'co', 'value': 'Napulione di Buonaparte'},
#    {'language': 'co', 'value': 'Napulione'}],
#   'ja': [{'language': 'ja', 'value': 'ナポレオーネ・ディ・ブオナパルテ'},
#    {'language': 'ja', 'value': 'ナポレオン1世'},
#    {'language': 'ja', 'value': 'ナブリオーネ・ブオナパルテ'},
#    {'language': 'ja', 'value': '那波烈翁'},
#    {'language': 'ja', 'value': 'ナポレオン'}],
#   'bn': [{'language': 'bn', 'value': 'নাপোলেওঁ বোনাপার্ত'},
#    {'language': 'bn', 'value': '১ম নেপোলিয়ন'}],
#   'ca': [{'language': 'ca', 'value': 'Napoleó I'},
#    {'language': 'ca', 'value': 'Napoleó Bonaparte I'}],
#   'pt': [{'language': 'pt', 'value': 'Napoleão'},
#    {'language': 'pt', 'value': 'Napoleon'},
#    {'language': 'pt', 'value': 'Napoleão I'}],
#   'sv': [{'language': 'sv', 'value': 'Napoleon Bonaparte'}],
#   'ro': [{'language': 'ro', 'value': 'Napoleon Bonaparte'}],
#   'sq': [{'language': 'sq', 'value': 'Napoleon Bonaparti'}],
#   'kw': [{'language': 'kw', 'value': 'Napoleon Bonaparte'}],
#   'id': [{'language': 'id', 'value': 'Napoleon Bonaparte'}],
#   'zea': [{'language': 'zea', 'value': 'Napoleon Bonaparte'}],
#   'gcr': [{'language': 'gcr', 'value': 'Napoléon Bonaparte'}],
#   'th': [{'language': 'th', 'value': 'นโปเลียน โบนาปาร์ต'}],
#   'gv': [{'language': 'gv', 'value': 'Napoleon'},
#    {'language': 'gv', 'value': 'Napoléon Bonaparte'},
#    {'language': 'gv', 'value': 'Napoleon Bonaparte'},
#    {'language': 'gv', 'value': 'Napoleon I'},
#    {'language': 'gv', 'value': 'Napoléon I'},
#    {'language': 'gv', 'value': 'Napoleone di Buonaparte'},
#    {'language': 'gv', 'value': 'Napulione Buonaparte'}],
#   'sl': [{'language': 'sl', 'value': 'Napolein'},
#    {'language': 'sl', 'value': 'Napoléon Bonaparte'},
#    {'language': 'sl', 'value': 'Bonaparte, Napoleon'},
#    {'language': 'sl', 'value': 'Napoleon I.'}],
#   'sco': [{'language': 'sco', 'value': 'Napoleon Bonaparte'}],
#   'jv': [{'language': 'jv', 'value': 'Napoleon Bonaparte'}],
#   'mt': [{'language': 'mt', 'value': 'Napuljun Bonaparti'}],
#   'yo': [{'language': 'yo', 'value': 'Napoléon Bonaparte'}],
#   'sw': [{'language': 'sw', 'value': 'Napoléon Bonaparte'}],
#   'an': [{'language': 'an', 'value': 'Napoleón Bonaparte'}],
#   'tl': [{'language': 'tl', 'value': 'Napoleon I'}],
#   'bew': [{'language': 'bew', 'value': 'Napoléon'}],
#   'tok': [{'language': 'tok', 'value': 'jan Napolejon'},
#    {'language': 'tok', 'value': 'jan Napolejon nanpa wan'},
#    {'language': 'tok', 'value': 'jan Napoléon Bonaparte'},
#    {'language': 'tok', 'value': 'jan Napoléon'},
#    {'language': 'tok', 'value': 'jan Napoleon Bonaparte'},
#    {'language': 'tok', 'value': 'jan Napoleon'}]},
#  'claims': {'P69': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P69',
#      'hash': '5d301dd2073d6a642325bc286c815f3062943643',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 273480,
#        'id': 'Q273480'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'qualifiers': {'P580': [{'snaktype': 'value',
#        'property': 'P580',
#        'hash': 'fabb4359c858d61012b85fad565d735556b1f26c',
#        'datavalue': {'value': {'time': '+1784-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'}]},
#     'qualifiers-order': ['P580'],
#     'id': 'Q517$dae5a3d8-4a61-59e9-be67-6ee6a6812d66',
#     'rank': 'normal'}],
#   'P106': [{'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '4b160f23716e832362b5802b7d10bdc4c8a499ab',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 82955,
#        'id': 'Q82955'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$b9930003-4065-c9d1-df8c-8dad6bd600ee',
#     'rank': 'normal',
#     'references': [{'hash': '934e78cb580dfc43a233aae4fa2d3ddf96ae5544',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '33e9cf0b06fa55d19dd6fb1d98c2f9e14254bde6',
#          'datavalue': {'value': 'http://www.smh.com.au/world/no-regrets-says-besieged-berlusconi-20110910-1k39j.html',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P1476': [{'snaktype': 'value',
#          'property': 'P1476',
#          'hash': 'dafde31ee88e7dea4df003606ac00edd3885c233',
#          'datavalue': {'value': {'text': 'No regrets, says besieged Berlusconi',
#            'language': 'en'},
#           'type': 'monolingualtext'},
#          'datatype': 'monolingualtext'}]},
#       'snaks-order': ['P854', 'P1476']},
#      {'hash': 'd986767507be4612ef8cbf7345154a2a17c20c7b',
#       'snaks': {'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '59bfa8a0f2b15db92526a25aadc1640156ce36d3',
#          'datavalue': {'value': 'http://www.encyclopedia.com/doc/1G2-3437703024.html',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P1476': [{'snaktype': 'value',
#          'property': 'P1476',
#          'hash': '8c5e4871b5fd94b2bbfac23dc1805e04cbd09217',
#          'datavalue': {'value': {'text': 'encyclopedia.com: Napoleonic Code',
#            'language': 'en'},
#           'type': 'monolingualtext'},
#          'datatype': 'monolingualtext'}]},
#       'snaks-order': ['P854', 'P1476']},
#      {'hash': 'c2130afebb087a30b83d0ac53fe6bd2c87cb0e15',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'd1e923075a89220a981d8c2511065b97bcf4dc5c',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 77541206,
#            'id': 'Q77541206'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P7796': [{'snaktype': 'value',
#          'property': 'P7796',
#          'hash': 'ff5903456219feda80ab5956f367dcf893e0d334',
#          'datavalue': {'value': '2194', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'a2c482c4381b8ce33ae32b3998e8ec614fedebb7',
#          'datavalue': {'value': {'time': '+2021-02-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P7796', 'P813']},
#      {'hash': '10f500dfe2b33979e9e5867122ddbad6ec9889c6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'a90160a2ce9deb340bb0a7e07b0d9c6106266546',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 10855166,
#            'id': 'Q10855166'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P6844': [{'snaktype': 'value',
#          'property': 'P6844',
#          'hash': 'cd64ae3c237cc4fc0090cda45c48481549c187e8',
#          'datavalue': {'value': '16142', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '735c5c4feacbf78b1310f9b1e73452a9bd6d335d',
#          'datavalue': {'value': 'https://cs.isabart.org/person/16142',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '6f8f333cebfac92bb111b2fdd9fcbf7697285918',
#          'datavalue': {'value': {'time': '+2021-04-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P6844', 'P854', 'P813']},
#      {'hash': '51ad638b1336cb84263ddf578d68a534bd9065ca',
#       'snaks': {'P227': [{'snaktype': 'value',
#          'property': 'P227',
#          'hash': 'c627e18a795a563999a065f4e9ec325ab2bc0c52',
#          'datavalue': {'value': '118586408', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': '61cfaea163998911779c4b634aba7f200ab3e0d0',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 23833686,
#            'id': 'Q23833686'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'f8ab6c654be250ebb391e5cb2e428325b3ccab71',
#          'datavalue': {'value': {'time': '+2025-01-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P227', 'P248', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': 'de86e22a6f2fe6e40e9ba768ca167f21b3a0f5b6',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 372436,
#        'id': 'Q372436'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$e484e675-4ced-6b61-5890-68e391f2c75e',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '2d6b623d4bfadf4a13d4602180bde083af86d51d',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 189290,
#        'id': 'Q189290'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$736DF581-253B-4F78-B84E-F069BC4C1933',
#     'rank': 'normal',
#     'references': [{'hash': 'c1b48834527bc85aca84ba209e3af1eecbbe3461',
#       'snaks': {'P143': [{'snaktype': 'value',
#          'property': 'P143',
#          'hash': '3e51278c4c89e53a5e0fd191932ecdded326439c',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 728945,
#            'id': 'Q728945'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'snaks-order': ['P143']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '2e87763277d3b9e62235d1f88314879ac52429e2',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 10732476,
#        'id': 'Q10732476'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$F281B789-3F3E-4069-880B-F0A5BC46931A',
#     'rank': 'normal',
#     'references': [{'hash': '100208bcafd73fe5333e2fa3e2d53d6d00a64c4e',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'dee3022ec24970657a992a2a969fffdc1236fbfb',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 17299517,
#            'id': 'Q17299517'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P650': [{'snaktype': 'value',
#          'property': 'P650',
#          'hash': 'fad08c4428037d4f842f7e27621d48108c45f717',
#          'datavalue': {'value': '434741', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '89640927183c0161730a8bd97961ec294d2f8bbf',
#          'datavalue': {'value': {'time': '+2025-12-12T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P650', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '199881076227f946dfdd9538f3ae3fbace83ee88',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 39018,
#        'id': 'Q39018'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$c558f4fd-41d9-b95e-bf55-1a054329672a',
#     'rank': 'normal',
#     'references': [{'hash': '80c3fe547fdd3387456bdbe6ab34fe2408fd80bf',
#       'snaks': {'P245': [{'snaktype': 'value',
#          'property': 'P245',
#          'hash': '20503b4e12be489828c6feb8883f6e3be21c9c5b',
#          'datavalue': {'value': '500122388', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'd61fad6998d07034c17af6b7d21f7a874053f2f6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 2494649,
#            'id': 'Q2494649'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P577': [{'snaktype': 'value',
#          'property': 'P577',
#          'hash': '71f0e3d2a7214e8a25070640883c817b3054a805',
#          'datavalue': {'value': {'time': '+2021-08-08T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'e8d06018a8ee0e6b7fb204f14c6745031f57e046',
#          'datavalue': {'value': {'time': '+2024-02-11T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P245', 'P248', 'P577', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': 'd7b995d21d82818590bf01f9b3c1681d9f8c9fd4',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 2304859,
#        'id': 'Q2304859'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$BEAAF539-F7E9-40F6-82E1-7DE499F549F8',
#     'rank': 'normal',
#     'references': [{'hash': '4b01a2bf666333dafd9d8fba144638f9902b659a',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'b2b692b28aebae2e58043249e3ac2691ffb7679a',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3621644,
#            'id': 'Q3621644'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P8290': [{'snaktype': 'value',
#          'property': 'P8290',
#          'hash': '4cd143a5758250dd7372892bf3172f03570dbdb4',
#          'datavalue': {'value': '15536', 'type': 'string'},
#          'datatype': 'external-id'}]},
#       'snaks-order': ['P248', 'P8290']},
#      {'hash': 'c2130afebb087a30b83d0ac53fe6bd2c87cb0e15',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'd1e923075a89220a981d8c2511065b97bcf4dc5c',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 77541206,
#            'id': 'Q77541206'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P7796': [{'snaktype': 'value',
#          'property': 'P7796',
#          'hash': 'ff5903456219feda80ab5956f367dcf893e0d334',
#          'datavalue': {'value': '2194', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'a2c482c4381b8ce33ae32b3998e8ec614fedebb7',
#          'datavalue': {'value': {'time': '+2021-02-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P7796', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '7dc35b2acf1fea0c6124901156ceb643041d9683',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 17010072,
#        'id': 'Q17010072'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$E8E82ECB-003E-4B76-B6DA-75D3A80CBFC7',
#     'rank': 'normal',
#     'references': [{'hash': 'c2130afebb087a30b83d0ac53fe6bd2c87cb0e15',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'd1e923075a89220a981d8c2511065b97bcf4dc5c',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 77541206,
#            'id': 'Q77541206'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P7796': [{'snaktype': 'value',
#          'property': 'P7796',
#          'hash': 'ff5903456219feda80ab5956f367dcf893e0d334',
#          'datavalue': {'value': '2194', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': 'a2c482c4381b8ce33ae32b3998e8ec614fedebb7',
#          'datavalue': {'value': {'time': '+2021-02-13T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P7796', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '30aa005ce5b8674961aa3bc55c1617369d24fd84',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 1402561,
#        'id': 'Q1402561'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$FA99FA84-3AEB-4529-830B-F533393E278B',
#     'rank': 'normal',
#     'references': [{'hash': '10f500dfe2b33979e9e5867122ddbad6ec9889c6',
#       'snaks': {'P248': [{'snaktype': 'value',
#          'property': 'P248',
#          'hash': 'a90160a2ce9deb340bb0a7e07b0d9c6106266546',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 10855166,
#            'id': 'Q10855166'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P6844': [{'snaktype': 'value',
#          'property': 'P6844',
#          'hash': 'cd64ae3c237cc4fc0090cda45c48481549c187e8',
#          'datavalue': {'value': '16142', 'type': 'string'},
#          'datatype': 'external-id'}],
#        'P854': [{'snaktype': 'value',
#          'property': 'P854',
#          'hash': '735c5c4feacbf78b1310f9b1e73452a9bd6d335d',
#          'datavalue': {'value': 'https://cs.isabart.org/person/16142',
#           'type': 'string'},
#          'datatype': 'url'}],
#        'P813': [{'snaktype': 'value',
#          'property': 'P813',
#          'hash': '6f8f333cebfac92bb111b2fdd9fcbf7697285918',
#          'datavalue': {'value': {'time': '+2021-04-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'snaks-order': ['P248', 'P6844', 'P854', 'P813']}]},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': 'b864da19341f12f5e95458570118a5cb4a6bcaa1',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 116,
#        'id': 'Q116'},
#       'type': 'wikibase-entityid'},
#      'datatype': 'wikibase-item'},
#     'type': 'statement',
#     'id': 'Q517$571CA8F9-E95F-492A-AB59-E96DFAFAEC40',
#     'rank': 'normal'},
#    {'mainsnak': {'snaktype': 'value',
#      'property': 'P106',
#      'hash': '664d5e6b17ab7dff9525fe00ca7bf886a76e4aef',
#      'datavalue': {'value': {'entity-type': 'item',
#        'numeric-id': 38239859,
#        'id': 'Q38239859'},
#       'type': 'wikibase-entityid'},
# ...
#   'plwiki': {'site': 'plwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://pl.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'plwikiquote': {'site': 'plwikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://pl.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'plwikisource': {'site': 'plwikisource',
#    'title': 'Autor:Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://pl.wikisource.org/wiki/Autor:Napoleon_Bonaparte'},
#   'pmswiki': {'site': 'pmswiki',
#    'title': 'Napoleon Bon-a-part',
#    'badges': [],
#    'url': 'https://pms.wikipedia.org/wiki/Napoleon_Bon-a-part'},
#   'pnbwiki': {'site': 'pnbwiki',
#    'title': 'نیپولین',
#    'badges': [],
#    'url': 'https://pnb.wikipedia.org/wiki/%D9%86%DB%8C%D9%BE%D9%88%D9%84%DB%8C%D9%86'},
#   'pswiki': {'site': 'pswiki',
#    'title': 'ناپليون بوناپارت',
#    'badges': [],
#    'url': 'https://ps.wikipedia.org/wiki/%D9%86%D8%A7%D9%BE%D9%84%D9%8A%D9%88%D9%86_%D8%A8%D9%88%D9%86%D8%A7%D9%BE%D8%A7%D8%B1%D8%AA'},
#   'ptwiki': {'site': 'ptwiki',
#    'title': 'Napoleão Bonaparte',
#    'badges': ['Q17437798'],
#    'url': 'https://pt.wikipedia.org/wiki/Napole%C3%A3o_Bonaparte'},
#   'ptwikiquote': {'site': 'ptwikiquote',
#    'title': 'Napoleão Bonaparte',
#    'badges': [],
#    'url': 'https://pt.wikiquote.org/wiki/Napole%C3%A3o_Bonaparte'},
#   'ptwikisource': {'site': 'ptwikisource',
#    'title': 'Autor:Napoleão Bonaparte',
#    'badges': [],
#    'url': 'https://pt.wikisource.org/wiki/Autor:Napole%C3%A3o_Bonaparte'},
#   'quwiki': {'site': 'quwiki',
#    'title': 'Napoléon Bonaparte',
#    'badges': [],
#    'url': 'https://qu.wikipedia.org/wiki/Napol%C3%A9on_Bonaparte'},
#   'rkiwiki': {'site': 'rkiwiki',
#    'title': 'နပိုလီယန်',
#    'badges': [],
#    'url': 'https://rki.wikipedia.org/wiki/%E1%80%94%E1%80%95%E1%80%AD%E1%80%AF%E1%80%9C%E1%80%AE%E1%80%9A%E1%80%94%E1%80%BA'},
#   'rmwiki': {'site': 'rmwiki',
#    'title': 'Napoleun Bonaparte',
#    'badges': [],
#    'url': 'https://rm.wikipedia.org/wiki/Napoleun_Bonaparte'},
#   'rnwiki': {'site': 'rnwiki',
#    'title': 'Napoléyoni',
#    'badges': [],
#    'url': 'https://rn.wikipedia.org/wiki/Napol%C3%A9yoni'},
#   'rowiki': {'site': 'rowiki',
#    'title': 'Napoleon I',
#    'badges': [],
#    'url': 'https://ro.wikipedia.org/wiki/Napoleon_I'},
#   'rowikiquote': {'site': 'rowikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://ro.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'ruewiki': {'site': 'ruewiki',
#    'title': 'Наполеон Бонапарт',
#    'badges': [],
#    'url': 'https://rue.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82'},
#   'ruwiki': {'site': 'ruwiki',
#    'title': 'Наполеон I',
#    'badges': ['Q17437796'],
#    'url': 'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I'},
#   'ruwikinews': {'site': 'ruwikinews',
#    'title': 'Категория:Наполеон I',
#    'badges': [],
#    'url': 'https://ru.wikinews.org/wiki/%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I'},
#   'ruwikiquote': {'site': 'ruwikiquote',
#    'title': 'Наполеон I Бонапарт',
#    'badges': [],
#    'url': 'https://ru.wikiquote.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82'},
#   'ruwikisource': {'site': 'ruwikisource',
#    'title': 'Автор:Наполеон I Бонапарт',
#    'badges': [],
#    'url': 'https://ru.wikisource.org/wiki/%D0%90%D0%B2%D1%82%D0%BE%D1%80:%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82'},
#   'sahwiki': {'site': 'sahwiki',
#    'title': 'Наполеон Бонапарт',
#    'badges': [],
#    'url': 'https://sah.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82'},
#   'satwiki': {'site': 'satwiki',
#    'title': 'ᱱᱮᱯᱳᱞᱤᱭᱚᱱ ᱵᱳᱱᱟᱯᱟᱨᱴ',
#    'badges': [],
#    'url': 'https://sat.wikipedia.org/wiki/%E1%B1%B1%E1%B1%AE%E1%B1%AF%E1%B1%B3%E1%B1%9E%E1%B1%A4%E1%B1%AD%E1%B1%9A%E1%B1%B1_%E1%B1%B5%E1%B1%B3%E1%B1%B1%E1%B1%9F%E1%B1%AF%E1%B1%9F%E1%B1%A8%E1%B1%B4'},
#   'sawiki': {'site': 'sawiki',
#    'title': 'नेपोलियन बोनापार्ट',
#    'badges': [],
#    'url': 'https://sa.wikipedia.org/wiki/%E0%A4%A8%E0%A5%87%E0%A4%AA%E0%A5%8B%E0%A4%B2%E0%A4%BF%E0%A4%AF%E0%A4%A8_%E0%A4%AC%E0%A5%8B%E0%A4%A8%E0%A4%BE%E0%A4%AA%E0%A4%BE%E0%A4%B0%E0%A5%8D%E0%A4%9F'},
#   'scnwiki': {'site': 'scnwiki',
#    'title': 'Napuliuni Bonaparti',
#    'badges': [],
#    'url': 'https://scn.wikipedia.org/wiki/Napuliuni_Bonaparti'},
#   'scowiki': {'site': 'scowiki',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://sco.wikipedia.org/wiki/Napoleon'},
#   'scwiki': {'site': 'scwiki',
#    'title': 'Napoleone Bonaparte',
#    'badges': [],
#    'url': 'https://sc.wikipedia.org/wiki/Napoleone_Bonaparte'},
#   'sdwiki': {'site': 'sdwiki',
#    'title': 'نئپولين بوناپارٽ',
#    'badges': [],
#    'url': 'https://sd.wikipedia.org/wiki/%D9%86%D8%A6%D9%BE%D9%88%D9%84%D9%8A%D9%86_%D8%A8%D9%88%D9%86%D8%A7%D9%BE%D8%A7%D8%B1%D9%BD'},
#   'shnwiki': {'site': 'shnwiki',
#    'title': 'ၼပူဝ်းလီးယၼ်း',
#    'badges': [],
#    'url': 'https://shn.wikipedia.org/wiki/%E1%81%BC%E1%80%95%E1%80%B0%E1%80%9D%E1%80%BA%E1%80%B8%E1%80%9C%E1%80%AE%E1%80%B8%E1%80%9A%E1%81%BC%E1%80%BA%E1%80%B8'},
#   'shwiki': {'site': 'shwiki',
#    'title': 'Napoleon I Bonaparte',
#    'badges': [],
#    'url': 'https://sh.wikipedia.org/wiki/Napoleon_I_Bonaparte'},
#   'simplewiki': {'site': 'simplewiki',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://simple.wikipedia.org/wiki/Napoleon'},
#   'simplewikiquote': {'site': 'simplewikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://simple.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'siwiki': {'site': 'siwiki',
#    'title': 'නැපෝලියන් බොනපාට්',
#    'badges': [],
#    'url': 'https://si.wikipedia.org/wiki/%E0%B6%B1%E0%B7%90%E0%B6%B4%E0%B7%9D%E0%B6%BD%E0%B7%92%E0%B6%BA%E0%B6%B1%E0%B7%8A_%E0%B6%B6%E0%B7%9C%E0%B6%B1%E0%B6%B4%E0%B7%8F%E0%B6%A7%E0%B7%8A'},
#   'skwiki': {'site': 'skwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sk.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'skwikiquote': {'site': 'skwikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sk.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'slwiki': {'site': 'slwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sl.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'slwikiquote': {'site': 'slwikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sl.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'smwiki': {'site': 'smwiki',
#    'title': 'Napoelon',
#    'badges': [],
#    'url': 'https://sm.wikipedia.org/wiki/Napoelon'},
#   'sowiki': {'site': 'sowiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://so.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'sqwiki': {'site': 'sqwiki',
#    'title': 'Napoleon Bonaparti',
#    'badges': [],
#    'url': 'https://sq.wikipedia.org/wiki/Napoleon_Bonaparti'},
#   'sqwikiquote': {'site': 'sqwikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sq.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'srwiki': {'site': 'srwiki',
#    'title': 'Наполеон I Бонапарта',
#    'badges': [],
#    'url': 'https://sr.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82%D0%B0'},
#   'srwikiquote': {'site': 'srwikiquote',
#    'title': 'Наполеон I Бонапарта',
#    'badges': [],
#    'url': 'https://sr.wikiquote.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82%D0%B0'},
#   'stqwiki': {'site': 'stqwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://stq.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'suwiki': {'site': 'suwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://su.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'svwiki': {'site': 'svwiki',
#    'title': 'Napoleon I',
#    'badges': [],
#    'url': 'https://sv.wikipedia.org/wiki/Napoleon_I'},
#   'svwikiquote': {'site': 'svwikiquote',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sv.wikiquote.org/wiki/Napoleon_Bonaparte'},
#   'swwiki': {'site': 'swwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://sw.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'szlwiki': {'site': 'szlwiki',
#    'title': 'Napoleůn Bůnaparte',
#    'badges': [],
#    'url': 'https://szl.wikipedia.org/wiki/Napole%C5%AFn_B%C5%AFnaparte'},
#   'szywiki': {'site': 'szywiki',
#    'title': 'Na-pu-lun-sakacacay',
#    'badges': [],
#    'url': 'https://szy.wikipedia.org/wiki/Na-pu-lun-sakacacay'},
#   'tawiki': {'site': 'tawiki',
#    'title': 'பிரான்சின் முதலாம் நெப்போலியன்',
#    'badges': [],
#    'url': 'https://ta.wikipedia.org/wiki/%E0%AE%AA%E0%AE%BF%E0%AE%B0%E0%AE%BE%E0%AE%A9%E0%AF%8D%E0%AE%9A%E0%AE%BF%E0%AE%A9%E0%AF%8D_%E0%AE%AE%E0%AF%81%E0%AE%A4%E0%AE%B2%E0%AE%BE%E0%AE%AE%E0%AF%8D_%E0%AE%A8%E0%AF%86%E0%AE%AA%E0%AF%8D%E0%AE%AA%E0%AF%8B%E0%AE%B2%E0%AE%BF%E0%AE%AF%E0%AE%A9%E0%AF%8D'},
#   'tawikiquote': {'site': 'tawikiquote',
#    'title': 'நெப்போலியன் பொனபார்ட்',
#    'badges': [],
#    'url': 'https://ta.wikiquote.org/wiki/%E0%AE%A8%E0%AF%86%E0%AE%AA%E0%AF%8D%E0%AE%AA%E0%AF%8B%E0%AE%B2%E0%AE%BF%E0%AE%AF%E0%AE%A9%E0%AF%8D_%E0%AE%AA%E0%AF%8A%E0%AE%A9%E0%AE%AA%E0%AE%BE%E0%AE%B0%E0%AF%8D%E0%AE%9F%E0%AF%8D'},
#   'tewiki': {'site': 'tewiki',
#    'title': 'నెపోలియన్',
#    'badges': [],
#    'url': 'https://te.wikipedia.org/wiki/%E0%B0%A8%E0%B1%86%E0%B0%AA%E0%B1%8B%E0%B0%B2%E0%B0%BF%E0%B0%AF%E0%B0%A8%E0%B1%8D'},
#   'thwiki': {'site': 'thwiki',
#    'title': 'จักรพรรดินโปเลียนที่ 1',
#    'badges': [],
#    'url': 'https://th.wikipedia.org/wiki/%E0%B8%88%E0%B8%B1%E0%B8%81%E0%B8%A3%E0%B8%9E%E0%B8%A3%E0%B8%A3%E0%B8%94%E0%B8%B4%E0%B8%99%E0%B9%82%E0%B8%9B%E0%B9%80%E0%B8%A5%E0%B8%B5%E0%B8%A2%E0%B8%99%E0%B8%97%E0%B8%B5%E0%B9%88_1'},
#   'thwikiquote': {'site': 'thwikiquote',
#    'title': 'จักรพรรดินโปเลียนที่ 1',
#    'badges': [],
#    'url': 'https://th.wikiquote.org/wiki/%E0%B8%88%E0%B8%B1%E0%B8%81%E0%B8%A3%E0%B8%9E%E0%B8%A3%E0%B8%A3%E0%B8%94%E0%B8%B4%E0%B8%99%E0%B9%82%E0%B8%9B%E0%B9%80%E0%B8%A5%E0%B8%B5%E0%B8%A2%E0%B8%99%E0%B8%97%E0%B8%B5%E0%B9%88_1'},
#   'tlwiki': {'site': 'tlwiki',
#    'title': 'Napoleon I ng Pransiya',
#    'badges': [],
#    'url': 'https://tl.wikipedia.org/wiki/Napoleon_I_ng_Pransiya'},
#   'tlywiki': {'site': 'tlywiki',
#    'title': 'Napoleon I',
#    'badges': [],
#    'url': 'https://tly.wikipedia.org/wiki/Napoleon_I'},
#   'tokwiki': {'site': 'tokwiki',
#    'title': 'jan Napolejon Ponapa',
#    'badges': [],
#    'url': 'https://tok.wikipedia.org/wiki/jan_Napolejon_Ponapa'},
#   'trwiki': {'site': 'trwiki',
#    'title': 'Napolyon Bonapart',
#    'badges': [],
#    'url': 'https://tr.wikipedia.org/wiki/Napolyon_Bonapart'},
#   'trwikiquote': {'site': 'trwikiquote',
#    'title': 'Napoléon Bonaparte',
#    'badges': [],
#    'url': 'https://tr.wikiquote.org/wiki/Napol%C3%A9on_Bonaparte'},
#   'ttwiki': {'site': 'ttwiki',
#    'title': 'Наполеон Бонапарт',
#    'badges': [],
#    'url': 'https://tt.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82'},
#   'twwiki': {'site': 'twwiki',
#    'title': 'Napoléon Bonaparte',
#    'badges': [],
#    'url': 'https://tw.wikipedia.org/wiki/Napol%C3%A9on_Bonaparte'},
#   'tyvwiki': {'site': 'tyvwiki',
#    'title': 'Наполеон I',
#    'badges': [],
#    'url': 'https://tyv.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I'},
#   'udmwiki': {'site': 'udmwiki',
#    'title': 'Наполеон',
#    'badges': [],
#    'url': 'https://udm.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD'},
#   'ugwiki': {'site': 'ugwiki',
#    'title': 'ﻧﺎﭘﻮﻟﯧﺌﻮﻥ ﺑﻮﻧﺎﭘﺎﺭﺕ',
#    'badges': [],
#    'url': 'https://ug.wikipedia.org/wiki/%EF%BB%A7%EF%BA%8E%EF%AD%98%EF%BB%AE%EF%BB%9F%EF%AF%A7%EF%BA%8C%EF%BB%AE%EF%BB%A5_%EF%BA%91%EF%BB%AE%EF%BB%A7%EF%BA%8E%EF%AD%98%EF%BA%8E%EF%BA%AD%EF%BA%95'},
#   'ukwiki': {'site': 'ukwiki',
#    'title': 'Наполеон',
#    'badges': [],
#    'url': 'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD'},
#   'ukwikiquote': {'site': 'ukwikiquote',
#    'title': 'Наполеон I Бонапарт',
#    'badges': [],
#    'url': 'https://uk.wikiquote.org/wiki/%D0%9D%D0%B0%D0%BF%D0%BE%D0%BB%D0%B5%D0%BE%D0%BD_I_%D0%91%D0%BE%D0%BD%D0%B0%D0%BF%D0%B0%D1%80%D1%82'},
#   'urwiki': {'site': 'urwiki',
#    'title': 'نپولین',
#    'badges': [],
#    'url': 'https://ur.wikipedia.org/wiki/%D9%86%D9%BE%D9%88%D9%84%DB%8C%D9%86'},
#   'uzwiki': {'site': 'uzwiki',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://uz.wikipedia.org/wiki/Napoleon'},
#   'uzwikiquote': {'site': 'uzwikiquote',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://uz.wikiquote.org/wiki/Napoleon'},
#   'vecwiki': {'site': 'vecwiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://vec.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'vepwiki': {'site': 'vepwiki',
#    'title': 'Napoleon I Bonapart',
#    'badges': [],
#    'url': 'https://vep.wikipedia.org/wiki/Napoleon_I_Bonapart'},
#   'viwiki': {'site': 'viwiki',
#    'title': 'Napoléon Bonaparte',
#    'badges': ['Q17437796'],
#    'url': 'https://vi.wikipedia.org/wiki/Napol%C3%A9on_Bonaparte'},
#   'viwikiquote': {'site': 'viwikiquote',
#    'title': 'Napoléon Bonaparte',
#    'badges': [],
#    'url': 'https://vi.wikiquote.org/wiki/Napol%C3%A9on_Bonaparte'},
#   'viwikisource': {'site': 'viwikisource',
#    'title': 'Tác gia:Napoléon Bonaparte',
#    'badges': [],
#    'url': 'https://vi.wikisource.org/wiki/T%C3%A1c_gia:Napol%C3%A9on_Bonaparte'},
#   'vlswiki': {'site': 'vlswiki',
#    'title': 'Napoleong',
#    'badges': [],
#    'url': 'https://vls.wikipedia.org/wiki/Napoleong'},
#   'warwiki': {'site': 'warwiki',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://war.wikipedia.org/wiki/Napoleon'},
#   'wawiki': {'site': 'wawiki',
#    'title': 'Napoleyon Bonapåre',
#    'badges': [],
#    'url': 'https://wa.wikipedia.org/wiki/Napoleyon_Bonap%C3%A5re'},
#   'wuuwiki': {'site': 'wuuwiki',
#    'title': '拿破仑',
#    'badges': [],
#    'url': 'https://wuu.wikipedia.org/wiki/%E6%8B%BF%E7%A0%B4%E4%BB%91'},
#   'xmfwiki': {'site': 'xmfwiki',
#    'title': 'ნაპოლეონ ბონაპარტი',
#    'badges': [],
#    'url': 'https://xmf.wikipedia.org/wiki/%E1%83%9C%E1%83%90%E1%83%9E%E1%83%9D%E1%83%9A%E1%83%94%E1%83%9D%E1%83%9C_%E1%83%91%E1%83%9D%E1%83%9C%E1%83%90%E1%83%9E%E1%83%90%E1%83%A0%E1%83%A2%E1%83%98'},
#   'yiwiki': {'site': 'yiwiki',
#    'title': 'נאפאלעאן באנאפארטע',
#    'badges': [],
#    'url': 'https://yi.wikipedia.org/wiki/%D7%A0%D7%90%D7%A4%D7%90%D7%9C%D7%A2%D7%90%D7%9F_%D7%91%D7%90%D7%A0%D7%90%D7%A4%D7%90%D7%A8%D7%98%D7%A2'},
#   'yowiki': {'site': 'yowiki',
#    'title': 'Napoleon Bonaparte',
#    'badges': [],
#    'url': 'https://yo.wikipedia.org/wiki/Napoleon_Bonaparte'},
#   'zawiki': {'site': 'zawiki',
#    'title': 'Nazbolunz',
#    'badges': [],
#    'url': 'https://za.wikipedia.org/wiki/Nazbolunz'},
#   'zeawiki': {'site': 'zeawiki',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://zea.wikipedia.org/wiki/Napoleon'},
#   'zh_classicalwiki': {'site': 'zh_classicalwiki',
#    'title': '拿破崙一世',
#    'badges': ['Q17437798'],
#    'url': 'https://zh-classical.wikipedia.org/wiki/%E6%8B%BF%E7%A0%B4%E5%B4%99%E4%B8%80%E4%B8%96'},
#   'zh_min_nanwiki': {'site': 'zh_min_nanwiki',
#    'title': 'Napoléon 1-sè',
#    'badges': [],
#    'url': 'https://zh-min-nan.wikipedia.org/wiki/Napol%C3%A9on_1-s%C3%A8'},
#   'zh_yuewiki': {'site': 'zh_yuewiki',
#    'title': '拿破崙',
#    'badges': [],
#    'url': 'https://zh-yue.wikipedia.org/wiki/%E6%8B%BF%E7%A0%B4%E5%B4%99'},
#   'zhwiki': {'site': 'zhwiki',
#    'title': '拿破仑一世',
#    'badges': ['Q17437796'],
#    'url': 'https://zh.wikipedia.org/wiki/%E6%8B%BF%E7%A0%B4%E4%BB%91%E4%B8%80%E4%B8%96'},
#   'zhwikiquote': {'site': 'zhwikiquote',
#    'title': '拿破仑',
#    'badges': [],
#    'url': 'https://zh.wikiquote.org/wiki/%E6%8B%BF%E7%A0%B4%E4%BB%91'},
#   'zuwiki': {'site': 'zuwiki',
#    'title': 'Napoleon',
#    'badges': [],
#    'url': 'https://zu.wikipedia.org/wiki/Napoleon'}}}

# %% [markdown]
# ## 3.2 API "On This Day" - Événements historiques par date

# %%
import requests
from datetime import datetime

def evenements_ce_jour(mois=None, jour=None):
    """Récupère les événements historiques pour une date donnée."""
    # Si pas de date spécifiée, utiliser aujourd'hui
    if mois is None or jour is None:
        aujourd_hui = datetime.now()
        mois = aujourd_hui.month
        jour = aujourd_hui.day
    
    # API Wikipedia "On this day"
    url = f"https://api.wikimedia.org/feed/v1/wikipedia/fr/onthisday/events/{mois}/{jour}"
    
    headers = {
        "User-Agent": "FormationPython/1.0"
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        
        evenements = data.get('events', [])
        
        print(f"📅 Événements du {jour}/{mois} dans l'histoire :")
        print("=" * 50)
        
        for e in evenements[:10]:  # Limiter à 10
            annee = e.get('year', '?')
            texte = e.get('text', 'N/A')
            print(f"\n{annee} : {texte}")
        
        return evenements
        
    except requests.exceptions.RequestException as e:
        print(f"Erreur : {e}")
        return []

# Événements du 14 juillet
#evenements_ce_jour(7, 14)

# Aujourd'hui
evenements_ce_jour()
# Out:
# 📅 Événements du 14/7 dans l'histoire :
# ==================================================
#
# 2024 : Une tentative d'assassinat a été commise contre le candidat à la présidentielle américaine Donald Trump.  L'agresseur qui a commis l'assassinat a été neutralisé par les membres du « Secret Service ».
#
# 2023 : aux États-Unis, les acteurs du syndicat SAG-AFTRA se mettent en grève, rejoignant les écrivains de la la Writers Guild of America qui eux sont grévistes depuis le 2 mai 2023.
#
# 2021 : début des inondations qui affectent l'Europe de l'Ouest et plus particulièrement l'Allemagne, la Belgique, le Luxembourg et les Pays-Bas avec un premier bilan de 42 morts.
#
# 2016 : attentat au camion à Nice (France, Côte d'Azur) sur la promenade des Anglais après la fin du feu d'artifice de fête nationale de la ville.
#
# 2014 : l'État islamique chasse les rebelles syriens de la ville de Deir ez-Zor, lors de la guerre civile syrienne.
#
# 1978 : fondation de la chaîne de télévision américaine consacrée au sport ESP-TV qui deviendra ESPN par la suite.
#
# 1969 : début de la guerre de Cent Heures.
#
# 1958 : destitution du roi Fayçal II d'Irak.
#
# 1953 : sept manifestants morts par balle lors du défilé du 14 juillet à Paris.
#
# 1945 : défilé de la 2e D.B. place de la Bastille, devant le général de Gaulle.
# [{'text': "Une tentative d'assassinat a été commise contre le candidat à la présidentielle américaine Donald Trump.  L'agresseur qui a commis l'assassinat a été neutralisé par les membres du «\xa0Secret Service\xa0».",
#   'pages': [{'type': 'standard',
#     'title': 'Donald_Trump',
#     'displaytitle': '<span class="mw-page-title-main">Donald Trump</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q22686',
#     'titles': {'canonical': 'Donald_Trump',
#      'normalized': 'Donald Trump',
#      'display': '<span class="mw-page-title-main">Donald Trump</span>'},
#     'pageid': 222336,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Official_Presidential_Portrait_of_President_Donald_J._Trump_%282025%29.jpg/330px-Official_Presidential_Portrait_of_President_Donald_J._Trump_%282025%29.jpg',
#      'width': 330,
#      'height': 412},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/1/16/Official_Presidential_Portrait_of_President_Donald_J._Trump_%282025%29.jpg',
#      'width': 3277,
#      'height': 4096},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232814890',
#     'tid': 'a3cae4f7-fc33-11f0-a280-bbe969b48d6c',
#     'timestamp': '2026-01-28T10:25:17Z',
#     'description': "homme d'affaires et homme d'État américain",
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Donald_Trump',
#       'revisions': 'https://fr.wikipedia.org/wiki/Donald_Trump?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Donald_Trump?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Donald_Trump'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Donald_Trump',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Donald_Trump',
#       'edit': 'https://fr.wikipedia.org/wiki/Donald_Trump?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Donald_Trump'}},
#     'extract': "Donald Trump, né le 14 juin 1946 à New York, est un homme d'affaires milliardaire, animateur, producteur de télévision et homme d'État américain. Membre du Parti républicain, il est le 45e et 47e\xa0président des États-Unis, en fonction du 20 janvier 2017 au 20 janvier 2021 et depuis le 20 janvier 2025.",
#     'extract_html': '<p><b>Donald Trump</b>, né le <time class="nowrap bday" datetime="1946-06-14">14 juin 1946</time> à New York, est un homme d\'affaires milliardaire, animateur, producteur de télévision et homme d\'État américain. Membre du Parti républicain, il est le <abbr class="abbr">45<sup>e</sup></abbr> et <abbr class="abbr">47<sup>e</sup></abbr>\xa0président des États-Unis, en fonction du <time class="nowrap" datetime="2017-01-20">20 janvier 2017</time> au <time class="nowrap" datetime="2021-01-20">20 janvier 2021</time> et depuis le <time class="nowrap" datetime="2025-01-20">20 janvier 2025</time>.</p>',
#     'normalizedtitle': 'Donald Trump'},
#    {'type': 'standard',
#     'title': 'United_States_Secret_Service',
#     'displaytitle': '<span lang="en">United States Secret Service</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q503224',
#     'titles': {'canonical': 'United_States_Secret_Service',
#      'normalized': 'United States Secret Service',
#      'display': '<span lang="en">United States Secret Service</span>'},
#     'pageid': 70269,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Logo_of_the_United_States_Secret_Service.svg/langfr-330px-Logo_of_the_United_States_Secret_Service.svg.png',
#      'width': 330,
#      'height': 325},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Logo_of_the_United_States_Secret_Service.svg/langfr-960px-Logo_of_the_United_States_Secret_Service.svg.png',
#      'width': 721,
#      'height': 709},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232529242',
#     'tid': 'b4be6e24-f45d-11f0-ae91-0d2138c329f6',
#     'timestamp': '2026-01-18T11:06:15Z',
#     'description': 'service de police aux États-Unis',
#     'description_source': 'central',
#     'coordinates': {'lat': 38.850878, 'lon': -77.016698},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/United_States_Secret_Service',
#       'revisions': 'https://fr.wikipedia.org/wiki/United_States_Secret_Service?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/United_States_Secret_Service?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:United_States_Secret_Service'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/United_States_Secret_Service',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/United_States_Secret_Service',
#       'edit': 'https://fr.wikipedia.org/wiki/United_States_Secret_Service?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:United_States_Secret_Service'}},
#     'extract': 'L’United States Secret Service (USSS) ou simplement «\xa0Secret Service\xa0» est une agence gouvernementale dépendant du département de la Sécurité intérieure des États-Unis.',
#     'extract_html': '<p>L’<b>United States Secret Service</b> (<b>USSS</b>) ou simplement «\xa0<b>Secret Service</b>\xa0» est une agence gouvernementale dépendant du département de la Sécurité intérieure des États-Unis.</p>',
#     'normalizedtitle': 'United States Secret Service'}],
#   'year': 2024},
#  {'text': 'aux États-Unis, les acteurs du syndicat SAG-AFTRA se mettent en grève, rejoignant les écrivains de la la Writers Guild of America qui eux sont grévistes depuis le 2 mai 2023.',
#   'pages': [{'type': 'standard',
#     'title': 'États-Unis',
#     'displaytitle': '<span class="mw-page-title-main">États-Unis</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q30',
#     'titles': {'canonical': 'États-Unis',
#      'normalized': 'États-Unis',
#      'display': '<span class="mw-page-title-main">États-Unis</span>'},
#     'pageid': 1377936,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/USA_orthographic.svg/langfr-330px-USA_orthographic.svg.png',
#      'width': 330,
#      'height': 330},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/USA_orthographic.svg/langfr-960px-USA_orthographic.svg.png',
#      'width': 551,
#      'height': 551},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232833210',
#     'tid': '9e07eb4f-fc99-11f0-80d7-0fb3d2cbf253',
#     'timestamp': '2026-01-28T22:35:16Z',
#     'description': "pays d'Amérique du Nord",
#     'description_source': 'central',
#     'coordinates': {'lat': 40, 'lon': -105},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/%C3%89tats-Unis',
#       'revisions': 'https://fr.wikipedia.org/wiki/%C3%89tats-Unis?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/%C3%89tats-Unis?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:%C3%89tats-Unis'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/%C3%89tats-Unis',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/%C3%89tats-Unis',
#       'edit': 'https://fr.wikipedia.org/wiki/%C3%89tats-Unis?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:%C3%89tats-Unis'}},
#     'extract': "Les États-Unis, en forme longue les États-Unis d'Amérique, également appelés de manière informelle les ÉU, les ÉUA, les US, les USA ou moins exactement l'Amérique, ou familièrement les States, sont un État transcontinental dont une large majorité du territoire se situe en Amérique du Nord. Les États-Unis ont la structure politique d'une république et d'un État fédéral à régime présidentiel, composé de cinquante États. La capitale fédérale, Washington, est située dans le district de Columbia, une zone enclavée dans l'Union, mais hors des cinquante États. Les États-Unis adoptent l'anglais comme langue officielle le 1er mars 2025, l'anglais américain ayant servi de facto de langue nationale depuis l'indépendance du pays. La monnaie est le dollar américain.",
#     'extract_html': '<p>Les <b>États-Unis</b>, en forme longue les <b>États-Unis d\'Amérique</b>, également appelés de manière informelle les <b>ÉU</b>, les <b>ÉUA</b>, les <b>US</b>, les <b>USA</b> ou moins exactement l\'<b>Amérique</b>, ou familièrement les <i><b>States</b></i>, sont un État transcontinental dont une large majorité du territoire se situe en Amérique du Nord. Les États-Unis ont la structure politique d\'une république et d\'un État fédéral à régime présidentiel, composé de cinquante États. La capitale fédérale, Washington, est située dans le district de Columbia, une zone enclavée dans l\'Union, mais hors des cinquante États. Les États-Unis adoptent l\'anglais comme langue officielle le <time class="nowrap" datetime="2025-03-01"><abbr class="abbr">1<sup>er</sup></abbr> mars 2025</time>, l\'anglais américain ayant servi <i>de facto</i> de langue nationale depuis l\'indépendance du pays. La monnaie est le dollar américain.</p>',
#     'normalizedtitle': 'États-Unis'},
#    {'type': 'standard',
#     'title': 'Grève_SAG-AFTRA_2023',
#     'displaytitle': '<span class="mw-page-title-main">Grève SAG-AFTRA 2023</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q120637995',
#     'titles': {'canonical': 'Grève_SAG-AFTRA_2023',
#      'normalized': 'Grève SAG-AFTRA 2023',
#      'display': '<span class="mw-page-title-main">Grève SAG-AFTRA 2023</span>'},
#     'pageid': 15757968,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fb/SAG-AFTRA_Picket_I_%2853051649802%29.jpg/330px-SAG-AFTRA_Picket_I_%2853051649802%29.jpg',
#      'width': 320,
#      'height': 180},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/f/fb/SAG-AFTRA_Picket_I_%2853051649802%29.jpg',
#      'width': 2528,
#      'height': 1422},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '228647252',
#     'tid': 'b75c591b-8823-11f0-a867-7ac123405563',
#     'timestamp': '2025-09-02T17:39:03Z',
#     'description': "grève syndicale opposant des professionnels de médias, d'artistes, de scénaristes et de réalisateurs contre une association de producteurs",
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_SAG-AFTRA_2023',
#       'revisions': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_SAG-AFTRA_2023?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_SAG-AFTRA_2023?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Gr%C3%A8ve_SAG-AFTRA_2023'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_SAG-AFTRA_2023',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Gr%C3%A8ve_SAG-AFTRA_2023',
#       'edit': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_SAG-AFTRA_2023?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Gr%C3%A8ve_SAG-AFTRA_2023'}},
#     'extract': "La grève SAG-AFTRA de 2023 est un conflit de travail entre le syndicat des acteurs d'Hollywood, SAG-AFTRA, et l'Alliance des producteurs de films et de télévision (AMPTP). La grève a débuté le 14 juillet 2023, après l'approbation du conseil d'administration national de SAG-AFTRA, et s'est terminée le 9 novembre de la même année, plus de trois mois après son lancement. La grève SAG-AFTRA et la grève de la Writers Guild of America (WGA), maintenant terminée, sont au cœur des conflits de travail à Hollywood en 2023.",
#     'extract_html': "<p>La <b>grève SAG-AFTRA de 2023</b> est un conflit de travail entre le syndicat des acteurs d'Hollywood, SAG-AFTRA, et l'Alliance des producteurs de films et de télévision (AMPTP). La grève a débuté le 14 juillet 2023, après l'approbation du conseil d'administration national de SAG-AFTRA, et s'est terminée le 9 novembre de la même année, plus de trois mois après son lancement. La grève SAG-AFTRA et la grève de la Writers Guild of America (WGA), maintenant terminée, sont au cœur des conflits de travail à Hollywood en 2023.</p>",
#     'normalizedtitle': 'Grève SAG-AFTRA 2023'},
#    {'type': 'standard',
#     'title': 'Grève_de_la_Writers_Guild_of_America_de_2023',
#     'displaytitle': '<span class="mw-page-title-main">Grève de la Writers Guild of America de 2023</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q118127692',
#     'titles': {'canonical': 'Grève_de_la_Writers_Guild_of_America_de_2023',
#      'normalized': 'Grève de la Writers Guild of America de 2023',
#      'display': '<span class="mw-page-title-main">Grève de la Writers Guild of America de 2023</span>'},
#     'pageid': 15753443,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/48/We_are_not_in_severance.jpg/330px-We_are_not_in_severance.jpg',
#      'width': 330,
#      'height': 248},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/4/48/We_are_not_in_severance.jpg',
#      'width': 4032,
#      'height': 3024},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '228647350',
#     'tid': '4538415d-8824-11f0-8a6e-71a560fc28cf',
#     'timestamp': '2025-09-02T17:43:01Z',
#     'description': 'grève aux États-Unis',
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023',
#       'revisions': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023',
#       'edit': 'https://fr.wikipedia.org/wiki/Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Gr%C3%A8ve_de_la_Writers_Guild_of_America_de_2023'}},
#     'extract': "La grève de la Writers Guild of America de 2023 est un conflit de travail entre la Writers Guild of America (WGA) —\xa0qui représente 11 500 scénaristes\xa0— et l'Alliance of Motion Picture and Television Producers\xa0(en) (AMPTP). Elle a débuté le 2 mai 2023 à 0h01 PDT, et s'est terminée le 27 septembre 2023 à 12h01 PDT.",
#     'extract_html': '<p>La <b>grève de la Writers Guild of America de 2023</b> est un conflit de travail entre la Writers Guild of America (WGA) —\xa0qui représente 11 500 scénaristes\xa0— et l\'Alliance of Motion Picture and Television Producers\xa0<span class="extiw"><span class="indicateur-langue">(en)</span></span> (AMPTP). Elle a débuté le 2 mai 2023 à 0h01 PDT, et s\'est terminée le 27 septembre 2023 à 12h01 PDT.</p>',
#     'normalizedtitle': 'Grève de la Writers Guild of America de 2023'}],
#   'year': 2023},
#  {'text': "début des inondations qui affectent l'Europe de l'Ouest et plus particulièrement l'Allemagne, la Belgique, le Luxembourg et les Pays-Bas avec un premier bilan de 42\xa0morts.",
#   'pages': [{'type': 'standard',
#     'title': 'Inondations_de_juillet_2021_en_Europe',
#     'displaytitle': '<span class="mw-page-title-main">Inondations de juillet 2021 en Europe</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q107529288',
#     'titles': {'canonical': 'Inondations_de_juillet_2021_en_Europe',
#      'normalized': 'Inondations de juillet 2021 en Europe',
#      'display': '<span class="mw-page-title-main">Inondations de juillet 2021 en Europe</span>'},
#     'pageid': 14249494,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/Geul-overstroming_juli_2021_%2855%29.jpg/330px-Geul-overstroming_juli_2021_%2855%29.jpg',
#      'width': 320,
#      'height': 180},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/3/33/Geul-overstroming_juli_2021_%2855%29.jpg',
#      'width': 4032,
#      'height': 2268},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '224362425',
#     'tid': 'a6df0710-0cea-11f0-bfd1-7cfc060bb944',
#     'timestamp': '2025-03-29T22:10:41Z',
#     'description': "fortes précipitations et inondations dans plusieurs pays européens au cours de l'été 2021",
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Inondations_de_juillet_2021_en_Europe',
#       'revisions': 'https://fr.wikipedia.org/wiki/Inondations_de_juillet_2021_en_Europe?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Inondations_de_juillet_2021_en_Europe?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Inondations_de_juillet_2021_en_Europe'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Inondations_de_juillet_2021_en_Europe',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Inondations_de_juillet_2021_en_Europe',
#       'edit': 'https://fr.wikipedia.org/wiki/Inondations_de_juillet_2021_en_Europe?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Inondations_de_juillet_2021_en_Europe'}},
#     'extract': "Les inondations de juillet 2021 en Europe affectent l'Europe de l'Ouest et plus particulièrement l'Allemagne, la Belgique, le Luxembourg et les Pays-Bas. Les 14 et 15 juillet 2021, les cours d'eau de plusieurs bassins fluviaux d'Europe de l'Ouest débordent, notamment l'Ahr en Rhénanie-du-Nord-Westphalie, provoquant une catastrophe naturelle. La crue est due à un niveau de précipitations record pour la saison. En Europe, il s'agit d'une des pires catastrophes naturelles du début du XXIe\xa0siècle en nombre de victimes.",
#     'extract_html': '<p>Les <b>inondations de <time class="nowrap" datetime="2021-07">juillet 2021</time> en Europe</b> affectent l\'Europe de l\'Ouest et plus particulièrement l\'Allemagne, la Belgique, le Luxembourg et les Pays-Bas. Les 14 et <time class="nowrap" datetime="2021-07-15">15 juillet 2021</time>, les cours d\'eau de plusieurs bassins fluviaux d\'Europe de l\'Ouest débordent, notamment l\'Ahr en Rhénanie-du-Nord-Westphalie, provoquant une catastrophe naturelle. La crue est due à un niveau de précipitations record pour la saison. En Europe, il s\'agit d\'une des pires catastrophes naturelles du début du <abbr class="abbr"><span class="romain">XXI</span><sup style="font-size:72%">e</sup></abbr>\xa0siècle en nombre de victimes.</p>',
#     'normalizedtitle': 'Inondations de juillet 2021 en Europe'},
#    {'type': 'standard',
#     'title': "Europe_de_l'Ouest",
#     'displaytitle': '<span class="mw-page-title-main">Europe de l&#039;Ouest</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q27496',
#     'titles': {'canonical': "Europe_de_l'Ouest",
#      'normalized': "Europe de l'Ouest",
#      'display': '<span class="mw-page-title-main">Europe de l&#039;Ouest</span>'},
#     'pageid': 77215,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Grossgliederung_Europas-fr.svg/langfr-330px-Grossgliederung_Europas-fr.svg.png',
#      'width': 330,
#      'height': 343},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3b/Grossgliederung_Europas-fr.svg/langfr-960px-Grossgliederung_Europas-fr.svg.png',
#      'width': 683,
#      'height': 709},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '230188957',
#     'tid': '0e6f66c7-b509-11f0-9299-5fe2ea482aae',
#     'timestamp': '2025-10-29T20:51:35Z',
#     'description': "région ouest de l'Europe",
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': "https://fr.wikipedia.org/wiki/Europe_de_l'Ouest",
#       'revisions': "https://fr.wikipedia.org/wiki/Europe_de_l'Ouest?action=history",
#       'edit': "https://fr.wikipedia.org/wiki/Europe_de_l'Ouest?action=edit",
#       'talk': "https://fr.wikipedia.org/wiki/Discussion:Europe_de_l'Ouest"},
#      'mobile': {'page': "https://fr.wikipedia.org/wiki/Europe_de_l'Ouest",
#       'revisions': "https://fr.wikipedia.org/wiki/Special:History/Europe_de_l'Ouest",
#       'edit': "https://fr.wikipedia.org/wiki/Europe_de_l'Ouest?action=edit",
#       'talk': "https://fr.wikipedia.org/wiki/Discussion:Europe_de_l'Ouest"}},
#     'extract': "L'Europe de l'Ouest est une région politique, géographique ou culturelle qui correspond à la partie occidentale de l'Europe, mais ce concept reste mal défini et équivoque. Depuis la chute du mur de Berlin, le concept d'Europe occidentale tend de plus en plus à remplacer celui d'Europe de l'Ouest.",
#     'extract_html': "<p>L'<b>Europe de l'Ouest</b> est une région politique, géographique ou culturelle qui correspond à la partie occidentale de l'Europe, mais ce concept reste mal défini et équivoque. Depuis la chute du mur de Berlin, le concept d'<b>Europe occidentale</b> tend de plus en plus à remplacer celui d'Europe de l'Ouest.</p>",
#     'normalizedtitle': "Europe de l'Ouest"},
#    {'type': 'standard',
#     'title': 'Allemagne',
#     'displaytitle': '<span class="mw-page-title-main">Allemagne</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q183',
#     'titles': {'canonical': 'Allemagne',
#      'normalized': 'Allemagne',
#      'display': '<span class="mw-page-title-main">Allemagne</span>'},
#     'pageid': 1590005,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/EU-Germany.svg/langfr-330px-EU-Germany.svg.png',
#      'width': 330,
#      'height': 278},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/EU-Germany.svg/langfr-3840px-EU-Germany.svg.png',
#      'width': 2045,
#      'height': 1720},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232751236',
#     'tid': '31e078c2-fa44-11f0-8c96-28aaee63d14e',
#     'timestamp': '2026-01-25T23:18:45Z',
#     'description': "pays d'Europe centrale",
#     'description_source': 'central',
#     'coordinates': {'lat': 52, 'lon': 10},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Allemagne',
#       'revisions': 'https://fr.wikipedia.org/wiki/Allemagne?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Allemagne?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Allemagne'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Allemagne',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Allemagne',
#       'edit': 'https://fr.wikipedia.org/wiki/Allemagne?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Allemagne'}},
#     'extract': "L'Allemagne, en forme longue la République fédérale d'Allemagne, est un État d'Europe centrale, et selon certaines définitions d'Europe de l'Ouest, entouré par la mer du Nord, le Danemark et la mer Baltique au nord, par la Pologne à l'est-nord-est, la Tchéquie à l'est-sud-est, l'Autriche au sud-sud-est, la Suisse au sud-sud-ouest, la France au sud-ouest, la Belgique et le Luxembourg à l'ouest, enfin par les Pays-Bas à l'ouest-nord-ouest. Décentralisée et fédérale, l'Allemagne compte quatre villes de plus d'un million d'habitants, par ordre décroissant la capitale Berlin, Hambourg, Munich et Cologne, mais les quatre plus grandes agglomérations sont Rhin-Ruhr, Francfort-sur-le-Main, Berlin et Stuttgart. Le siège du Gouvernement est situé dans la ville de Berlin et dans la ville fédérale de Bonn, ancienne capitale de la République fédérale d'Allemagne. Francfort-sur-le-Main est considérée comme la capitale financière de l'Allemagne et abrite le siège de la Banque centrale européenne. La langue officielle du pays est principalement l'allemand, à côté d'autres langues régionales ou minoritaires.",
#     'extract_html': "<p>L'<b>Allemagne</b>, en forme longue la <b>République fédérale d'Allemagne</b>, est un État d'Europe centrale, et selon certaines définitions d'Europe de l'Ouest, entouré par la mer du Nord, le Danemark et la mer Baltique au nord, par la Pologne à l'est-nord-est, la Tchéquie à l'est-sud-est, l'Autriche au sud-sud-est, la Suisse au sud-sud-ouest, la France au sud-ouest, la Belgique et le Luxembourg à l'ouest, enfin par les Pays-Bas à l'ouest-nord-ouest. Décentralisée et fédérale, l'Allemagne compte quatre villes de plus d'un million d'habitants, par ordre décroissant la capitale Berlin, Hambourg, Munich et Cologne, mais les quatre plus grandes agglomérations sont Rhin-Ruhr, Francfort-sur-le-Main, Berlin et Stuttgart. Le siège du Gouvernement est situé dans la ville de Berlin et dans la ville fédérale de Bonn, ancienne capitale de la République fédérale d'Allemagne. Francfort-sur-le-Main est considérée comme la capitale financière de l'Allemagne et abrite le siège de la Banque centrale européenne. La langue officielle du pays est principalement l'allemand, à côté d'autres langues régionales ou minoritaires.</p>",
#     'normalizedtitle': 'Allemagne'},
#    {'type': 'standard',
#     'title': 'Belgique',
#     'displaytitle': '<span class="mw-page-title-main">Belgique</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q31',
#     'titles': {'canonical': 'Belgique',
#      'normalized': 'Belgique',
#      'display': '<span class="mw-page-title-main">Belgique</span>'},
#     'pageid': 385,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/EU-Belgium.svg/langfr-330px-EU-Belgium.svg.png',
#      'width': 330,
#      'height': 278},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/6/67/EU-Belgium.svg/langfr-3840px-EU-Belgium.svg.png',
#      'width': 2045,
#      'height': 1720},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232634234',
#     'tid': '5d8df769-f704-11f0-9951-88dd04c1e805',
#     'timestamp': '2026-01-21T20:04:17Z',
#     'description': "État d'Europe occidentale",
#     'description_source': 'central',
#     'coordinates': {'lat': 50.64, 'lon': 4.67},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Belgique',
#       'revisions': 'https://fr.wikipedia.org/wiki/Belgique?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Belgique?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Belgique'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Belgique',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Belgique',
#       'edit': 'https://fr.wikipedia.org/wiki/Belgique?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Belgique'}},
#     'extract': "La Belgique, en forme longue le royaume de Belgique, est un pays d'Europe de l'Ouest, bordé par la France, les Pays-Bas, l'Allemagne, le Luxembourg et la mer du Nord. La Belgique couvre une superficie de 30\xa0688\xa0km2 avec une population de 11\xa0825\xa0551\xa0habitants au 1er janvier 2025, soit une densité de 385\xa0habitants/km2. Politiquement, il s'agit d'une monarchie constitutionnelle fédérale à régime parlementaire. Sa capitale est Bruxelles\xa0; les autres grandes villes sont Anvers, Gand, Charleroi, Liège, Bruges, Namur et Louvain.",
#     'extract_html': '<p>La <b>Belgique</b>, en forme longue le <b>royaume de Belgique</b>, est un pays d\'Europe de l\'Ouest, bordé par la France, les Pays-Bas, l\'Allemagne, le Luxembourg et la mer du Nord. La Belgique couvre une superficie de 30\xa0688\xa0<abbr class="abbr">km<sup>2</sup></abbr> avec une population de 11\xa0825\xa0551\xa0habitants au <time class="nowrap" datetime="2025-01-01"><abbr class="abbr">1<sup>er</sup></abbr> janvier 2025</time>, soit une densité de 385\xa0habitants/km<sup>2</sup>. Politiquement, il s\'agit d\'une monarchie constitutionnelle fédérale à régime parlementaire. Sa capitale est Bruxelles\xa0; les autres grandes villes sont Anvers, Gand, Charleroi, Liège, Bruges, Namur et Louvain.</p>',
#     'normalizedtitle': 'Belgique'},
#    {'type': 'standard',
#     'title': 'Luxembourg',
#     'displaytitle': '<span class="mw-page-title-main">Luxembourg</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q32',
#     'titles': {'canonical': 'Luxembourg',
#      'normalized': 'Luxembourg',
#      'display': '<span class="mw-page-title-main">Luxembourg</span>'},
#     'pageid': 1713,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/EU-Luxembourg.svg/langfr-330px-EU-Luxembourg.svg.png',
#      'width': 330,
#      'height': 278},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/EU-Luxembourg.svg/langfr-3840px-EU-Luxembourg.svg.png',
#      'width': 2045,
#      'height': 1720},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232252762',
#     'tid': 'b2f8ec47-eca2-11f0-922e-581fc921c0b0',
#     'timestamp': '2026-01-08T14:59:58Z',
#     'description': "pays du Nord-Ouest de l'Europe",
#     'description_source': 'central',
#     'coordinates': {'lat': 49.8, 'lon': 6.1},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Luxembourg',
#       'revisions': 'https://fr.wikipedia.org/wiki/Luxembourg?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Luxembourg?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Luxembourg'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Luxembourg',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Luxembourg',
#       'edit': 'https://fr.wikipedia.org/wiki/Luxembourg?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Luxembourg'}},
#     'extract': "Le Luxembourg, en forme longue le Grand-Duché de Luxembourg ou grand-duché de Luxembourg, est un pays d'Europe de l'Ouest sans accès à la mer. Il est bordé par la Belgique à l'ouest et au nord, l'Allemagne à l'est, et la France au sud. Il comprend deux régions principales\xa0: l'Oesling au nord, qui est une partie du massif de l'Ardenne, et le Gutland au sud, prolongement de la Lorraine au sens géologique du terme. Le Luxembourg compte 681\xa0973\xa0habitants au 1er janvier 2025, et s'étend sur 2\xa0586\xa0km2, ce qui fait de lui l'une des plus petites nations souveraines d'Europe.",
#     'extract_html': '<p>Le <b>Luxembourg</b>, en forme longue le <b>Grand-Duché de Luxembourg</b> ou <b>grand-duché de Luxembourg</b>, est un pays d\'Europe de l\'Ouest sans accès à la mer. Il est bordé par la Belgique à l\'ouest et au nord, l\'Allemagne à l\'est, et la France au sud. Il comprend deux régions principales\xa0: l\'Oesling au nord, qui est une partie du massif de l\'Ardenne, et le Gutland au sud, prolongement de la Lorraine au sens géologique du terme. Le Luxembourg compte 681\xa0973\xa0habitants au <time class="nowrap" datetime="2025-01-01"><abbr class="abbr">1<sup>er</sup></abbr> janvier 2025</time>, et s\'étend sur 2\xa0586\xa0<abbr class="abbr">km<sup>2</sup></abbr>, ce qui fait de lui l\'une des plus petites nations souveraines d\'Europe.</p>',
#     'normalizedtitle': 'Luxembourg'},
#    {'type': 'standard',
#     'title': 'Pays-Bas',
#     'displaytitle': '<span class="mw-page-title-main">Pays-Bas</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q29999',
#     'titles': {'canonical': 'Pays-Bas',
#      'normalized': 'Pays-Bas',
#      'display': '<span class="mw-page-title-main">Pays-Bas</span>'},
#     'pageid': 2304,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/EU-Netherlands.svg/langfr-330px-EU-Netherlands.svg.png',
#      'width': 330,
#      'height': 278},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/EU-Netherlands.svg/langfr-3840px-EU-Netherlands.svg.png',
#      'width': 2045,
#      'height': 1720},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232451074',
#     'tid': '99b2ebac-f220-11f0-a8dc-78274c71e8d6',
#     'timestamp': '2026-01-15T14:43:48Z',
#     'description': 'État souverain et monarchie constitutionnelle transcontinentale',
#     'description_source': 'central',
#     'coordinates': {'lat': 52.32, 'lon': 5.55},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Pays-Bas',
#       'revisions': 'https://fr.wikipedia.org/wiki/Pays-Bas?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Pays-Bas?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Pays-Bas'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Pays-Bas',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Pays-Bas',
#       'edit': 'https://fr.wikipedia.org/wiki/Pays-Bas?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Pays-Bas'}},
#     'extract': "Les Pays-Bas, en forme longue le royaume des Pays-Bas, parfois appelés la Hollande par métonymie, sont un pays transcontinental dont le territoire métropolitain est situé en Europe du Nord-Ouest et le territoire d'outre-mer, dans les Antilles.",
#     'extract_html': "<p>Les <b>Pays-Bas</b>, en forme longue le <b>royaume des Pays-Bas</b>, parfois appelés la <b>Hollande</b> par métonymie, sont un pays transcontinental dont le territoire métropolitain est situé en Europe du Nord-Ouest et le territoire d'outre-mer, dans les Antilles.</p>",
#     'normalizedtitle': 'Pays-Bas'}],
#   'year': 2021},
#  {'text': "attentat au camion à Nice (France, Côte d'Azur) sur la promenade des Anglais après la fin du feu d'artifice de fête nationale de la ville.",
#   'pages': [{'type': 'standard',
#     'title': 'Attentat_du_14_juillet_2016_à_Nice',
#     'displaytitle': '<span class="mw-page-title-main">Attentat du 14 juillet 2016 à Nice</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q25893254',
#     'titles': {'canonical': 'Attentat_du_14_juillet_2016_à_Nice',
#      'normalized': 'Attentat du 14 juillet 2016 à Nice',
#      'display': '<span class="mw-page-title-main">Attentat du 14 juillet 2016 à Nice</span>'},
#     'pageid': 10143362,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ae/H%C3%B4tel_Negresco_04.jpg/330px-H%C3%B4tel_Negresco_04.jpg',
#      'width': 320,
#      'height': 240},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/a/ae/H%C3%B4tel_Negresco_04.jpg',
#      'width': 4000,
#      'height': 3000},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232644162',
#     'tid': 'fb66dd10-f767-11f0-bc5c-69ad762e43fc',
#     'timestamp': '2026-01-22T07:57:22Z',
#     'description': "attaque terroriste islamiste au moyen d'un camion-bélier",
#     'description_source': 'central',
#     'coordinates': {'lat': 43.694523, 'lon': 7.260107},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Attentat_du_14_juillet_2016_%C3%A0_Nice',
#       'revisions': 'https://fr.wikipedia.org/wiki/Attentat_du_14_juillet_2016_%C3%A0_Nice?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Attentat_du_14_juillet_2016_%C3%A0_Nice?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Attentat_du_14_juillet_2016_%C3%A0_Nice'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Attentat_du_14_juillet_2016_%C3%A0_Nice',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Attentat_du_14_juillet_2016_%C3%A0_Nice',
#       'edit': 'https://fr.wikipedia.org/wiki/Attentat_du_14_juillet_2016_%C3%A0_Nice?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Attentat_du_14_juillet_2016_%C3%A0_Nice'}},
#     'extract': "L'attentat du 14 juillet 2016 à Nice est une attaque terroriste islamiste au camion-bélier, qui s'est déroulée à Nice dans la soirée du 14 juillet 2016 sur la promenade des Anglais.",
#     'extract_html': '<p>L\'<b>attentat du 14 juillet 2016 à Nice</b> est une attaque terroriste islamiste au camion-bélier, qui s\'est déroulée à Nice dans la soirée du <time class="nowrap" datetime="2016-07-14">14 juillet 2016</time> sur la promenade des Anglais.</p>',
#     'normalizedtitle': 'Attentat du 14 juillet 2016 à Nice'},
#    {'type': 'standard',
#     'title': 'Promenade_des_Anglais',
#     'displaytitle': '<span class="mw-page-title-main">Promenade des Anglais</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q1849491',
#     'titles': {'canonical': 'Promenade_des_Anglais',
#      'normalized': 'Promenade des Anglais',
#      'display': '<span class="mw-page-title-main">Promenade des Anglais</span>'},
#     'pageid': 146301,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Promenadedesanglais.jpg/330px-Promenadedesanglais.jpg',
#      'width': 330,
#      'height': 248},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/8/80/Promenadedesanglais.jpg',
#      'width': 2576,
#      'height': 1932},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '231897822',
#     'tid': 'a1971ff3-e414-11f0-a0ea-a9b95a389478',
#     'timestamp': '2025-12-28T17:42:51Z',
#     'description': 'voie de Nice, en France',
#     'description_source': 'central',
#     'coordinates': {'lat': 43.691, 'lon': 7.24759},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Promenade_des_Anglais',
#       'revisions': 'https://fr.wikipedia.org/wiki/Promenade_des_Anglais?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Promenade_des_Anglais?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Promenade_des_Anglais'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Promenade_des_Anglais',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Promenade_des_Anglais',
#       'edit': 'https://fr.wikipedia.org/wiki/Promenade_des_Anglais?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Promenade_des_Anglais'}},
#     'extract': "La promenade des Anglais ou Prom' est une avenue longeant le bord de mer face à la baie des Anges, à Nice. Son histoire, liée aux débuts du tourisme international, et sa situation exceptionnelle, en bord de mer, longée par des hôtels prestigieux, en font l'une des plus célèbres avenues du monde.",
#     'extract_html': "<p>La <b>promenade des Anglais</b> ou <b>Prom'</b> est une avenue longeant le bord de mer face à la baie des Anges, à Nice. Son histoire, liée aux débuts du tourisme international, et sa situation exceptionnelle, en bord de mer, longée par des hôtels prestigieux, en font l'une des plus célèbres avenues du monde.</p>",
#     'normalizedtitle': 'Promenade des Anglais'}],
#   'year': 2016},
#  {'text': "l'État islamique chasse les rebelles syriens de la ville de Deir ez-Zor, lors de la guerre civile syrienne.",
#   'pages': [{'type': 'standard',
#     'title': 'État_islamique_(organisation)',
#     'displaytitle': '<span class="mw-page-title-main">État islamique (organisation)</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q2429253',
#     'titles': {'canonical': 'État_islamique_(organisation)',
#      'normalized': 'État islamique (organisation)',
#      'display': '<span class="mw-page-title-main">État islamique (organisation)</span>'},
#     'pageid': 7665926,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Flag_of_the_Islamic_State_of_Iraq_and_the_Levant2.svg/langfr-330px-Flag_of_the_Islamic_State_of_Iraq_and_the_Levant2.svg.png',
#      'width': 330,
#      'height': 248},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Flag_of_the_Islamic_State_of_Iraq_and_the_Levant2.svg/langfr-1280px-Flag_of_the_Islamic_State_of_Iraq_and_the_Levant2.svg.png',
#      'width': 1280,
#      'height': 960},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232526443',
#     'tid': 'ba6186d3-f450-11f0-9c15-127202352cef',
#     'timestamp': '2026-01-18T09:33:21Z',
#     'description': "organisation terroriste, militaire et politique, d'idéologie salafiste djihadiste",
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/%C3%89tat_islamique_(organisation)',
#       'revisions': 'https://fr.wikipedia.org/wiki/%C3%89tat_islamique_(organisation)?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/%C3%89tat_islamique_(organisation)?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:%C3%89tat_islamique_(organisation)'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/%C3%89tat_islamique_(organisation)',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/%C3%89tat_islamique_(organisation)',
#       'edit': 'https://fr.wikipedia.org/wiki/%C3%89tat_islamique_(organisation)?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:%C3%89tat_islamique_(organisation)'}},
#     'extract': "L'État islamique, aussi appelé Daech, est une organisation terroriste politico-militaire, d'idéologie djihadiste ayant proclamé le 29 juin 2014 l'instauration d'un califat sur les territoires sous son contrôle. De l'été 2014 au printemps 2019, il forme un proto-État en Irak et en Syrie où il met en place un système totalitaire. Son essor est notamment lié aux déstabilisations géopolitiques causées par la guerre d'Irak et la guerre civile syrienne.",
#     'extract_html': '<p>L\'<b>État islamique</b>, aussi appelé <b>Daech</b>, est une organisation terroriste politico-militaire, d\'idéologie djihadiste ayant proclamé le <time class="nowrap" datetime="2014-06-29">29 juin 2014</time> l\'instauration d\'un califat sur les territoires sous son contrôle. De l\'été 2014 au printemps 2019, il forme un proto-État en Irak et en Syrie où il met en place un système totalitaire. Son essor est notamment lié aux déstabilisations géopolitiques causées par la guerre d\'Irak et la guerre civile syrienne.</p>',
#     'normalizedtitle': 'État islamique (organisation)'},
#    {'type': 'standard',
#     'title': 'Bataille_de_Deir_ez-Zor',
#     'displaytitle': '<span class="mw-page-title-main">Bataille de Deir ez-Zor</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q28419687',
#     'titles': {'canonical': 'Bataille_de_Deir_ez-Zor',
#      'normalized': 'Bataille de Deir ez-Zor',
#      'display': '<span class="mw-page-title-main">Bataille de Deir ez-Zor</span>'},
#     'pageid': 8544715,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7b/Deir_ez_Zor_street_fighting.png/330px-Deir_ez_Zor_street_fighting.png',
#      'width': 320,
#      'height': 243},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/7/7b/Deir_ez_Zor_street_fighting.png',
#      'width': 1012,
#      'height': 768},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '229806599',
#     'tid': 'e35732f6-aa85-11f0-85d2-89f0716156ce',
#     'timestamp': '2025-10-16T11:47:27Z',
#     'description': 'bataille de la guerre civile syrienne',
#     'description_source': 'central',
#     'coordinates': {'lat': 35.33333333, 'lon': 40.15},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Bataille_de_Deir_ez-Zor',
#       'revisions': 'https://fr.wikipedia.org/wiki/Bataille_de_Deir_ez-Zor?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Bataille_de_Deir_ez-Zor?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Bataille_de_Deir_ez-Zor'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Bataille_de_Deir_ez-Zor',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Bataille_de_Deir_ez-Zor',
#       'edit': 'https://fr.wikipedia.org/wiki/Bataille_de_Deir_ez-Zor?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Bataille_de_Deir_ez-Zor'}},
#     'extract': "La bataille de Deir ez-Zor a lieu lors de la guerre civile syrienne. De 2012 à 2014, elle oppose le régime syrien et les rebelles pour le contrôle de la ville de Deir ez-Zor. Le 14 juillet 2014, les djihadistes de l'État islamique supplantent les forces d'opposition et les chassent totalement du gouvernorat de Deir ez-Zor, prenant au cours d'une offensive le contrôle de la moitié de la ville et de la totalité de la province. Seule la partie ouest de la ville, ainsi que l'aéroport situé au sud-est, demeurent aux mains du régime syrien. L'État islamique poursuit alors les combats pour tenter de prendre les quartiers encore aux mains des loyalistes. D'importantes offensives sont menées par les djihadistes, principalement en décembre 2014, en janvier 2016 et en janvier 2017. Elles leur permettent de gagner du terrain et d'isoler l'aéroport le 16 janvier 2017, mais pas d'emporter la totalité de la ville. Finalement une offensive de l'armée syrienne et de ses alliés permet au régime de briser le siège de Deir ez-Zor le 5 septembre 2017, puis de reprendre entièrement la ville le 2 novembre 2017.",
#     'extract_html': '<p>La <b>bataille de Deir ez-Zor</b> a lieu lors de la guerre civile syrienne. De 2012 à 2014, elle oppose le régime syrien et les rebelles pour le contrôle de la ville de Deir ez-Zor. Le <time class="nowrap" datetime="2014-07-14">14 juillet 2014</time>, les djihadistes de l\'État islamique supplantent les forces d\'opposition et les chassent totalement du gouvernorat de Deir ez-Zor, prenant au cours d\'une offensive le contrôle de la moitié de la ville et de la totalité de la province. Seule la partie ouest de la ville, ainsi que l\'aéroport situé au sud-est, demeurent aux mains du régime syrien. L\'État islamique poursuit alors les combats pour tenter de prendre les quartiers encore aux mains des loyalistes. D\'importantes offensives sont menées par les djihadistes, principalement en décembre 2014, en janvier 2016 et en janvier 2017. Elles leur permettent de gagner du terrain et d\'isoler l\'aéroport le <time class="nowrap" datetime="2017-01-16">16 janvier 2017</time>, mais pas d\'emporter la totalité de la ville. Finalement une offensive de l\'armée syrienne et de ses alliés permet au régime de briser le siège de Deir ez-Zor le <time class="nowrap" datetime="2017-09-05">5 septembre 2017</time>, puis de reprendre entièrement la ville le <time class="nowrap" datetime="2017-11-02">2 novembre 2017</time>.</p>',
#     'normalizedtitle': 'Bataille de Deir ez-Zor'},
#    {'type': 'standard',
#     'title': 'Deir_ez-Zor',
#     'displaytitle': '<span class="mw-page-title-main">Deir ez-Zor</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q239097',
#     'titles': {'canonical': 'Deir_ez-Zor',
#      'normalized': 'Deir ez-Zor',
#      'display': '<span class="mw-page-title-main">Deir ez-Zor</span>'},
#     'pageid': 2927511,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Deir_ez-Zour-March8Square_front.jpg/330px-Deir_ez-Zour-March8Square_front.jpg',
#      'width': 330,
#      'height': 248},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/7/7c/Deir_ez-Zour-March8Square_front.jpg',
#      'width': 2048,
#      'height': 1536},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232632947',
#     'tid': 'ce7ce231-f6fb-11f0-9578-6dc6ec3606aa',
#     'timestamp': '2026-01-21T19:03:01Z',
#     'description': 'ville de Syrie',
#     'description_source': 'central',
# ...
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Louis_VIII_le_Lion'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Louis_VIII_le_Lion',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Louis_VIII_le_Lion',
#       'edit': 'https://fr.wikipedia.org/wiki/Louis_VIII_le_Lion?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Louis_VIII_le_Lion'}},
#     'extract': 'Louis\xa0VIII dit «\xa0le Lion\xa0», né le 5 septembre 1187 à Paris et mort le 8 novembre 1226 à Montpensier (Auvergne), est roi de France de 1223 à 1226, huitième de la dynastie dite des Capétiens directs.',
#     'extract_html': '<p><b>Louis\xa0<abbr class="abbr"><span class="romain" style="text-transform:uppercase">VIII</span></abbr></b> dit «\xa0le Lion\xa0», né le <time class="nowrap bday" datetime="1187-09-12">5 septembre 1187</time> à Paris et mort le <time class="nowrap dday" datetime="1226-11-15">8 novembre 1226</time> à Montpensier (Auvergne), est roi de France de 1223 à 1226, huitième de la dynastie dite des Capétiens directs.</p>',
#     'normalizedtitle': 'Louis VIII le Lion'},
#    {'type': 'standard',
#     'title': 'Liste_des_monarques_de_France',
#     'displaytitle': '<span class="mw-page-title-main">Liste des monarques de France</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q79868',
#     'titles': {'canonical': 'Liste_des_monarques_de_France',
#      'normalized': 'Liste des monarques de France',
#      'display': '<span class="mw-page-title-main">Liste des monarques de France</span>'},
#     'pageid': 8634,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Family_tree_of_French_monarchs_509%E2%80%931870.svg/langfr-330px-Family_tree_of_French_monarchs_509%E2%80%931870.svg.png',
#      'width': 320,
#      'height': 791},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Family_tree_of_French_monarchs_509%E2%80%931870.svg/langfr-3840px-Family_tree_of_French_monarchs_509%E2%80%931870.svg.png',
#      'width': 2000,
#      'height': 4945},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232599309',
#     'tid': '3dcbd757-f615-11f0-a728-ff1a3b458e43',
#     'timestamp': '2026-01-20T15:32:34Z',
#     'description': 'page de liste de Wikimédia',
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Liste_des_monarques_de_France',
#       'revisions': 'https://fr.wikipedia.org/wiki/Liste_des_monarques_de_France?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Liste_des_monarques_de_France?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Liste_des_monarques_de_France'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Liste_des_monarques_de_France',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Liste_des_monarques_de_France',
#       'edit': 'https://fr.wikipedia.org/wiki/Liste_des_monarques_de_France?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Liste_des_monarques_de_France'}},
#     'extract': "La liste des monarques de France réunit les rois et les empereurs qui ont régné sur la France, au travers des différentes constructions politiques, territoriales et dynastiques qui se succédèrent\xa0: Mérovingiens, Carolingiens, Capétiens et Bonaparte. Parmi les différents moments de cette monarchie française, on distingue l'époque des royaumes francs au haut Moyen Âge, la Francie occidentale issue du partage au IXe\xa0siècle de l'Empire carolingien, le royaume de France en tant que tel jusqu'à la Révolution française, puis le Premier Empire, la Restauration, la monarchie de Juillet et enfin le Second Empire. Le dernier monarque ayant régné en France est l'empereur Napoléon III, déchu officiellement le 1er mars 1871, après la défaite de Sedan. Jusqu'alors, la France avait toujours été un royaume ou un empire, hormis durant deux périodes\xa0: la Première République, du 22 septembre 1792 au 18 mai 1804, et la Deuxième République, du 24 février 1848 au 2 décembre 1852.",
#     'extract_html': '<p>La <b>liste des monarques de France</b> réunit les rois et les empereurs qui ont régné sur la France, au travers des différentes constructions politiques, territoriales et dynastiques qui se succédèrent\xa0: Mérovingiens, Carolingiens, Capétiens et Bonaparte. Parmi les différents moments de cette monarchie française, on distingue l\'époque des royaumes francs au haut Moyen Âge, la Francie occidentale issue du partage au <abbr class="abbr"><span class="romain">IX</span><sup style="font-size:72%">e</sup></abbr>\xa0siècle de l\'Empire carolingien, le royaume de France en tant que tel jusqu\'à la Révolution française, puis le Premier Empire, la Restauration, la monarchie de Juillet et enfin le Second Empire. Le dernier monarque ayant régné en France est l\'empereur <span><span><span class="nowrap">Napoléon <abbr class="abbr"><span class="romain" style="text-transform:uppercase">III</span></abbr></span></span></span>, déchu officiellement le <time class="nowrap" datetime="1871-03-01"><abbr class="abbr">1<sup>er</sup></abbr> mars 1871</time>, après la défaite de Sedan. Jusqu\'alors, la France avait toujours été un royaume ou un empire, hormis durant deux périodes\xa0: la Première République, du <time class="nowrap" datetime="1792-09-22">22 septembre 1792</time> au <time class="nowrap" datetime="1804-05-18">18 mai 1804</time>, et la Deuxième République, du <time class="nowrap" datetime="1848-02-24">24 février 1848</time> au <time class="nowrap" datetime="1852-12-02">2 décembre 1852</time>.</p>',
#     'normalizedtitle': 'Liste des monarques de France'},
#    {'type': 'standard',
#     'title': 'Philippe_II_Auguste',
#     'displaytitle': 'Philippe&#160;<abbr class="abbr" title="2"><span class="romain" style="text-transform:uppercase">II</span></abbr> Auguste',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q34428',
#     'titles': {'canonical': 'Philippe_II_Auguste',
#      'normalized': 'Philippe II Auguste',
#      'display': 'Philippe&#160;<abbr class="abbr" title="2"><span class="romain" style="text-transform:uppercase">II</span></abbr> Auguste'},
#     'pageid': 32579,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Sceau_de_Philippe_Auguste._-_Archives_Nationales_-_SC-D157.jpg/330px-Sceau_de_Philippe_Auguste._-_Archives_Nationales_-_SC-D157.jpg',
#      'width': 330,
#      'height': 331},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/d/dc/Sceau_de_Philippe_Auguste._-_Archives_Nationales_-_SC-D157.jpg',
#      'width': 511,
#      'height': 512},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232827114',
#     'tid': '16a8806e-fc75-11f0-beeb-7e22d1b33f77',
#     'timestamp': '2026-01-28T18:13:47Z',
#     'description': 'roi de France de 1180 à 1223, inaugurateur du titre',
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Philippe_II_Auguste',
#       'revisions': 'https://fr.wikipedia.org/wiki/Philippe_II_Auguste?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Philippe_II_Auguste?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Philippe_II_Auguste'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Philippe_II_Auguste',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Philippe_II_Auguste',
#       'edit': 'https://fr.wikipedia.org/wiki/Philippe_II_Auguste?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Philippe_II_Auguste'}},
#     'extract': "Philippe\xa0II dit «\xa0Auguste\xa0», né le 21 août 1165 à Paris et mort à Mantes le 14 juillet 1223, est le septième roi (1180-1223) de la dynastie des Capétiens et le premier monarque auquel est attribué le titre de roi de France. Il est le fils héritier de Louis\xa0VII et d'Adèle de Champagne.",
#     'extract_html': '<p><b>Philippe\xa0<abbr class="abbr"><span class="romain" style="text-transform:uppercase">II</span></abbr></b> dit «\xa0Auguste\xa0», né le <time class="nowrap" datetime="1165-08-28">21 août 1165</time> à Paris et mort à Mantes le <time class="nowrap" datetime="1223-07-21">14 juillet 1223</time>, est le septième roi (1180-1223) de la dynastie des Capétiens et le premier monarque auquel est attribué le titre de roi de France. Il est le fils héritier de <span>Louis\xa0<abbr class="abbr"><span class="romain" style="text-transform:uppercase">VII</span></abbr></span> et d\'Adèle de Champagne.</p>',
#     'normalizedtitle': 'Philippe II Auguste'},
#    {'type': 'standard',
#     'title': 'Londres',
#     'displaytitle': '<span class="mw-page-title-main">Londres</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q84',
#     'titles': {'canonical': 'Londres',
#      'normalized': 'Londres',
#      'display': '<span class="mw-page-title-main">Londres</span>'},
#     'pageid': 4924,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/London_Montage_L.jpg/330px-London_Montage_L.jpg',
#      'width': 330,
#      'height': 497},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/c/cd/London_Montage_L.jpg',
#      'width': 1200,
#      'height': 1809},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232086918',
#     'tid': '52ce0869-e8a4-11f0-9092-acccf4f178c3',
#     'timestamp': '2026-01-03T13:01:31Z',
#     'description': "capitale de l'Angleterre et du Royaume-Uni",
#     'description_source': 'central',
#     'coordinates': {'lat': 51.507222, 'lon': -0.1275},
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Londres',
#       'revisions': 'https://fr.wikipedia.org/wiki/Londres?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Londres?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Londres'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Londres',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Londres',
#       'edit': 'https://fr.wikipedia.org/wiki/Londres?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Londres'}},
#     'extract': "Londres est la capitale et plus grande ville d'Angleterre et du Royaume-Uni. La ville est située près de l'estuaire de la Tamise dans le sud-est de l'Angleterre. Londinium est fondée par les Romains il y a presque 2\xa0000\xa0ans. La Cité de Londres, le noyau historique de Londres avec une superficie de seulement 1,12\xa0mile carré conserve des frontières qui suivent de près ses limites médiévales. Londres est gouvernée par le maire de Londres et l'Assemblée de Londres.",
#     'extract_html': '<p><b>Londres</b> est la capitale et plus grande ville d\'Angleterre et du Royaume-Uni. La ville est située près de l\'estuaire de la Tamise dans le sud-est de l\'Angleterre. <i>Londinium</i> est fondée par les Romains il y a presque 2\xa0000\xa0ans. La Cité de Londres, le noyau historique de Londres avec une superficie de seulement 1,12\xa0<abbr class="abbr">mile</abbr> carré conserve des frontières qui suivent de près ses limites médiévales. Londres est gouvernée par le maire de Londres et l\'Assemblée de Londres.</p>',
#     'normalizedtitle': 'Londres'},
#    {'type': 'standard',
#     'title': 'Louis_IX',
#     'displaytitle': 'Louis&#160;<abbr class="abbr" title="9"><span class="romain" style="text-transform:uppercase">IX</span></abbr>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q346',
#     'titles': {'canonical': 'Louis_IX',
#      'normalized': 'Louis IX',
#      'display': 'Louis&#160;<abbr class="abbr" title="9"><span class="romain" style="text-transform:uppercase">IX</span></abbr>'},
#     'pageid': 8668,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/de/Saintlouis_%28cropped%29.jpg/330px-Saintlouis_%28cropped%29.jpg',
#      'width': 330,
#      'height': 480},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/d/de/Saintlouis_%28cropped%29.jpg',
#      'width': 849,
#      'height': 1234},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232501974',
#     'tid': 'c8a59a15-f3a3-11f0-8a1c-d73b824e089e',
#     'timestamp': '2026-01-17T12:55:22Z',
#     'description': "roi de France capétien de 1226 à 1270 canonisé par l'Église catholique",
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Louis_IX',
#       'revisions': 'https://fr.wikipedia.org/wiki/Louis_IX?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Louis_IX?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Louis_IX'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Louis_IX',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Louis_IX',
#       'edit': 'https://fr.wikipedia.org/wiki/Louis_IX?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Louis_IX'}},
#     'extract': "Louis\xa0IX, parfois dit «\xa0le Prud'homme\xa0» et plus communément appelé Saint Louis, est un roi de France capétien né le 25 avril 1214 à Poissy et mort le 25 août 1270 à Carthage, près de Tunis. Il régna pendant plus de 43 ans, de 1226 jusqu'à sa mort. Considéré comme un saint de son vivant, il est canonisé par l'Église catholique en 1297.",
#     'extract_html': '<p><b>Louis\xa0<abbr class="abbr"><span class="romain" style="text-transform:uppercase">IX</span></abbr></b>, parfois dit <span class="citation">«\xa0le Prud\'homme\xa0»</span> et plus communément appelé <b>Saint Louis</b>, est un roi de France capétien né le <time class="nowrap bday" datetime="1214-05-02">25 avril 1214</time> à Poissy et mort le <time class="nowrap dday" datetime="1270-09-01">25 août 1270</time> à Carthage, près de Tunis. Il régna pendant plus de <span class="nowrap">43 ans</span>, de 1226 jusqu\'à sa mort. Considéré comme un saint de son vivant, il est canonisé par l\'Église catholique en 1297.</p>',
#     'normalizedtitle': 'Louis IX'},
#    {'type': 'standard',
#     'title': 'Blanche_de_Castille',
#     'displaytitle': '<span class="mw-page-title-main">Blanche de Castille</span>',
#     'namespace': {'id': 0, 'text': ''},
#     'wikibase_item': 'Q353',
#     'titles': {'canonical': 'Blanche_de_Castille',
#      'normalized': 'Blanche de Castille',
#      'display': '<span class="mw-page-title-main">Blanche de Castille</span>'},
#     'pageid': 3264144,
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Blancheofcastile.jpg/330px-Blancheofcastile.jpg',
#      'width': 330,
#      'height': 386},
#     'originalimage': {'source': 'https://upload.wikimedia.org/wikipedia/commons/c/c3/Blancheofcastile.jpg',
#      'width': 1229,
#      'height': 1438},
#     'lang': 'fr',
#     'dir': 'ltr',
#     'revision': '232613717',
#     'tid': '232749c2-f671-11f0-a25e-0de16b433251',
#     'timestamp': '2026-01-21T02:30:23Z',
#     'description': 'princesse espagnole, reine de France, régente de France, puis reine-mère de France',
#     'description_source': 'central',
#     'content_urls': {'desktop': {'page': 'https://fr.wikipedia.org/wiki/Blanche_de_Castille',
#       'revisions': 'https://fr.wikipedia.org/wiki/Blanche_de_Castille?action=history',
#       'edit': 'https://fr.wikipedia.org/wiki/Blanche_de_Castille?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Blanche_de_Castille'},
#      'mobile': {'page': 'https://fr.wikipedia.org/wiki/Blanche_de_Castille',
#       'revisions': 'https://fr.wikipedia.org/wiki/Special:History/Blanche_de_Castille',
#       'edit': 'https://fr.wikipedia.org/wiki/Blanche_de_Castille?action=edit',
#       'talk': 'https://fr.wikipedia.org/wiki/Discussion:Blanche_de_Castille'}},
#     'extract': 'Blanche de Castille est reine de France par son mariage avec Louis\xa0VIII.',
#     'extract_html': '<p><b>Blanche de Castille</b> est reine de France par son mariage avec <span>Louis\xa0<abbr class="abbr"><span class="romain" style="text-transform:uppercase">VIII</span></abbr></span>.</p>',
#     'normalizedtitle': 'Blanche de Castille'}],
#   'year': 1223}]

# %% [markdown]
# ## 3.3 API Open Library - Livres historiques

# %%
import requests

def rechercher_livres_historiques(sujet):
    """Recherche des livres sur un sujet historique."""
    url = "https://openlibrary.org/search.json"
    params = {
        "q": sujet,
        "subject": "history",
        "language": "fre",
        "limit": 10
    }
    
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        
        livres = data.get('docs', [])
        
        print(f"📚 Livres sur '{sujet}' ({data.get('numFound', 0)} résultats) :")
        print("-" * 60)
        
        for livre in livres[:5]:
            titre = livre.get('title', 'N/A')
            auteurs = livre.get('author_name', ['Inconnu'])
            annee = livre.get('first_publish_year', '?')
            
            print(f"\n📖 {titre}")
            print(f"   Auteur(s) : {', '.join(auteurs[:3])}")
            print(f"   Première publication : {annee}")
        
        return livres
        
    except requests.exceptions.RequestException as e:
        print(f"Erreur : {e}")
        return []

# Rechercher des livres sur la Révolution française
rechercher_livres_historiques("révolution française")

# %% [markdown]
# ---
# # Partie 4 : Exercices avancés

# %% [markdown]
# ## Exercice 10 : Créer un quiz historique
#
# Créez un quiz interactif qui pose des questions sur les événements historiques français.

# %%
import random

def quiz_historique(evenements, nb_questions=5):
    """Quiz sur les événements historiques."""
    print("🎓 Quiz d'Histoire de France")
    print("=" * 40)
    
    score = 0
    questions_posees = random.sample(evenements, min(nb_questions, len(evenements)))
    
    for i, evenement in enumerate(questions_posees, 1):
        print(f"\nQuestion {i}/{nb_questions}")
        print(f"En quelle année a eu lieu : {evenement['titre']} ?")
        
        # Proposer des choix
        bonne_reponse = evenement['annee']
        choix = [bonne_reponse]
        
        # Générer de fausses réponses proches
        while len(choix) < 4:
            faux = bonne_reponse + random.choice([-50, -20, -10, 10, 20, 50])
            if faux not in choix and faux > 0:
                choix.append(faux)
        
        random.shuffle(choix)
        
        for j, c in enumerate(choix, 1):
            print(f"  {j}. {c}")
        
        try:
            reponse = int(input("Votre réponse (1-4) : "))
            if choix[reponse - 1] == bonne_reponse:
                print("✅ Correct !")
                score += 1
            else:
                print(f"❌ Faux ! La réponse était {bonne_reponse}")
        except (ValueError, IndexError):
            print(f"❌ Réponse invalide. La réponse était {bonne_reponse}")
    
    print(f"\n🏆 Score final : {score}/{nb_questions}")
    return score

# Décommenter pour jouer
# quiz_historique(evenements, 5)

# %% [markdown]
# ## Exercice 11 : Comparer des périodes historiques
#
# Créez une fonction qui compare deux périodes de l'histoire de France.

# %%
def comparer_periodes(evenements, periode1, periode2):
    """
    Compare deux périodes historiques.
    periode1 et periode2 sont des tuples (debut, fin)
    """
    def filtrer(debut, fin):
        return [e for e in evenements if debut <= e['annee'] <= fin]
    
    ev1 = filtrer(*periode1)
    ev2 = filtrer(*periode2)
    
    print(f"📊 Comparaison des périodes")
    print("=" * 50)
    
    print(f"\nPériode 1 ({periode1[0]}-{periode1[1]}) :")
    print(f"  Nombre d'événements : {len(ev1)}")
    if ev1:
        categories1 = Counter(e['categorie'] for e in ev1)
        print(f"  Catégories : {dict(categories1)}")
    
    print(f"\nPériode 2 ({periode2[0]}-{periode2[1]}) :")
    print(f"  Nombre d'événements : {len(ev2)}")
    if ev2:
        categories2 = Counter(e['categorie'] for e in ev2)
        print(f"  Catégories : {dict(categories2)}")

# Comparer l'Ancien Régime et la Révolution
# comparer_periodes(evenements, (1700, 1788), (1789, 1815))

# %% [markdown]
# ## Exercice 12 : Générer un rapport historique
#
# Créez une fonction qui génère un rapport complet sur une période donnée.

# %%
def generer_rapport(rois, evenements, demographie, debut, fin):
    """
    Génère un rapport historique complet pour une période donnée.
    """
    print(f"\n{'='*60}")
    print(f"📜 RAPPORT HISTORIQUE : {debut} - {fin}")
    print(f"{'='*60}")
    
    # Rois de la période
    rois_periode = [
        r for r in rois 
        if int(r['debut_regne']) <= fin and int(r['fin_regne']) >= debut
    ]
    
    print(f"\n👑 SOUVERAINS ({len(rois_periode)})")
    print("-" * 40)
    for roi in rois_periode:
        print(f"  • {roi['nom']} ({roi['debut_regne']}-{roi['fin_regne']})")
        print(f"    Dynastie : {roi['dynastie']}")
    
    # Événements de la période
    ev_periode = [e for e in evenements if debut <= e['annee'] <= fin]
    ev_periode = sorted(ev_periode, key=lambda e: e['annee'])
    
    print(f"\n📅 ÉVÉNEMENTS MAJEURS ({len(ev_periode)})")
    print("-" * 40)
    for e in ev_periode:
        print(f"  • {e['annee']} : {e['titre']}")
    
    # Démographie
    demo_periode = [
        d for d in demographie 
        if debut <= int(d['annee']) <= fin
    ]
    
    if demo_periode:
        print(f"\n📊 DÉMOGRAPHIE")
        print("-" * 40)
        for d in demo_periode:
            print(f"  • {d['annee']} : {int(d['population']):,} habitants")
    
    print(f"\n{'='*60}")

# Générer un rapport pour le XVIIIe siècle
# generer_rapport(rois, evenements, demographie, 1700, 1800)

# %% [markdown]
# ---
# # Partie 5 : Projet final
#
# ## Créer une application interactive d'exploration historique
#
# Combinez tout ce que vous avez appris pour créer une application qui permet à l'utilisateur d'explorer l'histoire de France.

# %%
def application_histoire():
    """Application interactive d'exploration de l'histoire de France."""
    
    # Charger les données
    try:
        rois = charger_rois_france()
        evenements = charger_evenements()
        demographie = charger_demographie()
        print("✅ Données chargées avec succès !")
    except FileNotFoundError as e:
        print(f"❌ Erreur de chargement : {e}")
        return
    
    print("\n" + "="*50)
    print("🏰 EXPLORATEUR D'HISTOIRE DE FRANCE")
    print("="*50)
    
    while True:
        print("\nQue souhaitez-vous explorer ?")
        print("1. Rechercher un roi")
        print("2. Explorer une période")
        print("3. Quiz historique")
        print("4. Événements d'une date (API)")
        print("5. Quitter")
        
        choix = input("\nVotre choix (1-5) : ")
        
        if choix == "1":
            nom = input("Nom du roi à rechercher : ")
            resultats = [r for r in rois if nom.lower() in r['nom'].lower()]
            if resultats:
                for r in resultats:
                    print(f"\n👑 {r['nom']}")
                    print(f"   Règne : {r['debut_regne']} - {r['fin_regne']}")
                    print(f"   Dynastie : {r['dynastie']}")
            else:
                print("Aucun roi trouvé.")
        
        elif choix == "2":
            try:
                debut = int(input("Année de début : "))
                fin = int(input("Année de fin : "))
                generer_rapport(rois, evenements, demographie, debut, fin)
            except ValueError:
                print("Veuillez entrer des années valides.")
        
        elif choix == "3":
            quiz_historique(evenements, 5)
        
        elif choix == "4":
            try:
                mois = int(input("Mois (1-12) : "))
                jour = int(input("Jour (1-31) : "))
                evenements_ce_jour(mois, jour)
            except ValueError:
                print("Date invalide.")
        
        elif choix == "5":
            print("\nAu revoir ! 👋")
            break
        
        else:
            print("Choix invalide.")

# Lancer l'application (décommenter pour utiliser)
# application_histoire()

# %% [markdown]
# ---
# # Résumé
#
# Dans ce notebook, nous avons appris à :
#
# 1. **Charger des données historiques** depuis des fichiers CSV et JSON
# 2. **Analyser des chronologies** : dynasties, règnes, événements
# 3. **Manipuler des dates** : calcul de durées, filtrage par siècle
# 4. **Utiliser des APIs** : Wikidata, Wikipedia "On This Day", Open Library
# 5. **Créer des statistiques** : comptages, tendances, comparaisons
# 6. **Générer des rapports** et des quiz interactifs
#
# ## Pour aller plus loin
#
# - Explorer d'autres APIs historiques (Europeana, Gallica, Archives Nationales)
# - Ajouter des visualisations avec matplotlib
# - Créer une base de données SQLite pour stocker les données
# - Développer une interface web avec Flask ou Streamlit
